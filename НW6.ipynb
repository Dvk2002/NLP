# %% [markdown]
# <a href="https://colab.research.google.com/github/Dvk2002/NLP/blob/main/%D0%9DW6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -O imdb.zip -qq --no-check-certificate "https://drive.google.com/uc?export=download&id=1vrQ5czMHoO3pEnmofFskymXMkq_u1dPc"
# !unzip imdb.zip
# !pip -q install eli5
# !pip -q install spacy
# !python -m spacy download en
# Out:
# Archive:  imdb.zip
#   inflating: test.tsv
#   inflating: train.tsv
#      |████████████████████████████████| 106 kB 4.2 MB/s
# Collecting en_core_web_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 4.9 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.41.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (57.2.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.19.5)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.6.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.10)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %% [markdown]
# ### Тут придется авторизировать запрос к гугл драйву, извините.

# %%
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once per notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

downloaded = drive.CreateFile({'id': '1d1-5FwxK53ePwygNWeG7jhsOWZbi5HOv'})
downloaded.GetContentFile('train_docs.pkl')

downloaded = drive.CreateFile({'id': '1MMOY477t965G0C5DtXeREVp0X85UaNq5'})
downloaded.GetContentFile('test_docs.pkl')

# %% [markdown]
# # Классификация текстов
#
# Начнём с самого простого - анализа тональности текста.
#
# Будем классифицировать отзывы с IMDB на положительные/отрицательные.
#
# Датасет взят с http://ai.stanford.edu/~amaas/data/sentiment/

# %%
# !head train.tsv
# Out:
# is_positive	review
# 0	"Dreamgirls, despite its fistful of Tony wins in an incredibly weak year on Broadway, has never been what one would call a jewel in the crown of stage musicals. However, that is not to say that in the right cinematic hands it could not be fleshed out and polished into something worthwhile on-screen. Unfortunately, what transfers to the screen is basically a slavishly faithful version of the stage hit with all of its inherent weaknesses intact. First, the score has never been one of the strong points of this production and the film does not change that factor. There are lots of songs (perhaps too many?), but few of them are especially memorable. The closest any come to catchy tunes are the title song and One Night Only - the much acclaimed And I Am Telling You That I Am Not Going is less a great song than it is a dramatic set piece for the character of Effie (Jennifer Hudson). The film is slick and technically well-produced, but the story and characters are surprisingly thin and lacking in any resonance. There is some interest in the opening moments, watching Jamie Foxx's Svengali-like manager manipulate his acts to the top, but that takes a back seat in the latter portion of the film, when the story conveniently tries to cast him as a villain, despite his having been right from a business stand-point for a good majority of the film. Beyonce Knowles is lovely and sings her songs perfectly well, but is stuck with a character who is basically all surface glitz. Anika Noni Rose as the third member of the Dreamgirls trio literally has nothing to do for the entire film. Eddie Murphy acquits himself well as a singer obviously based on James Brown, but the role is not especially meaty and ultimately has little impact. Foxx would seem ideal casting, but he seems oddly withdrawn and bored. The film's biggest selling point is surely former American Idol contestant/Oscar winner Jennifer Hudson in the central role of Effie White, the temperamental singer who gets booted from the group and makes a triumphant closing act return. For me, Effie has always been a big problem in both the show and the movie. The film obviously wants you to feel sorry for her and rather ham-handedly takes her side, but I have never been sure that this character deserves that kind of devotion. From the start, Effie conducts herself for the most part like an obnoxious, egotistical, self-centered diva, who is more interested in what everyone else can do for her rather than having much vested interest in the group of which she is a part. When she is booted from the group for her unprofessionalism and bad attitude, the charges are more than well-founded, but the stage show/film seem to think Effie should be cut unlimited slack simply because she has a great voice. Even though the film tries to soften some of Effie's harder edges to make her more likable, the charges still stand. Her story becomes more manipulative by suggesting she should have our further sympathy because she is an unwed mother struggling to raise her daughter - using the implication that (much like the talent card) motherhood immediately makes any behavior excusable. Indeed the only big effort the film makes to show Effie's mothering is to tell us about it and then include a scene where she barks at her daughter in the unemployment office, insists that the girl has ""no father"" and then refuse to look for gainful employment to support them since singing is all she knows. In the hands of a skillful actress, the gaps could perhaps have been remedied with technique and charisma. Unfortunately, Hudson is not that actress. She sings well, but the dialog-driven moments do not come naturally to her nor do high emotional moments. Effie's signature moment (the aforementioned And I Am Telling You... number) is well-sung by Hudson, but emotionally flat in the acting department. Effie is supposed to expressing her rage and desperation at her predicament, but Hudson comes off as a cabaret performer belting out  ...
# 0	This show comes up with interesting locations as fast as the travel channel. It is billed as reality but in actuality it is pure prime time soap opera. It's tries to use exotic locales as a facade to bring people into a phony contest & then proceeds to hook viewers on the contestants soap opera style.<br /><br />It also borrows from an early CBS game show pioneer- Beat The Clock- by inventing situations for its contestants to try & overcome. Then it rewards the winner money. If they can spice it up with a little interaction between the characters, even better. While the game format is in slow motion versus Beat The Clock- the real accomplishment of this series is to escape reality. <br /><br />This show has elements of several types of successful past programs. Reality television, hardly, but if your hooked on the contestants, locale or contest, this is your cup of tea. If your not, this entire series is as I say, drivel dripping with gravy. It is another show hiding behind the reality label which is the trend it started in 2000.<br /><br />It is slick & well produced, so it might last a while yet. After all, so do re-runs of Gilligan's Island, Green Acres, The Beverly Hillbillies & The Brady Bunch. This just doesn't employ professional actors. The intelligence level is about the same.
# 1	I simply love this movie. I also love the Ramones, so I am sorta biased to begin with in the first place. There isn't a lot of critical praise to give this film, either you like it or you don't. I think it's a great cult movie.
# 0	"Spoilers ahead if you want to call them that...<br /><br />I would almost recommend this film just so people can truly see a 1/10. Where to begin, we'll start from the top...<br /><br />THE STORY: Don't believe the premise - the movie has nothing to do with abandoned cars, and people finially understanding what the mysterious happenings are. It's a draub, basic, go to cabin movie with no intensity or ""effort"".<br /><br />THE SCREENPLAY: I usually give credit to indie screenwriters, it's hard work when you are starting out...but this is crap. The story is flat - it leaves you emotionless the entire movie. The dialogue is extremely weak and predictable boasting lines of ""Woah, you totally freaked me out"" and ""I was wondering if you'd uh...if you'd like to..uh, would you come to the cabin with me?"". It makes me want to rip out all my hair, one strand at a time and feed it to myself.<br /><br />THE CHARACTERS: HOLY CRAP!!!! Some have described the characters as flat, I want to take it one step further and say that they actually have a reverse character arch.. They actually start working on a parallel universe and almost start acting backwards...<br /><br />THE ACTORS: Worse than the characters are the actors. They take already poor written characters and add in terrible high school drama acting. The ""Woah you totally freaked me out"" was said so monotone and slow - like it was dumbed down. I could complain for hours on the actors alone.<br /><br />TECHNICAL: LIGHTING: An eight year old would be disappointed with lighting on this movie. Too shadowy in areas, too bleached in others. The director shouldn't use light as an emotion until he learns how to light a basic scene properly. Baby Steps! SOUND: How many sound guys does it take to make a really shotty sounding movie? 9. With that many sound guys this should sound amazing but quite the opposite has occured. There is one scene in particular that really sticks out, these guys are driving in a car and the sound of the car changes with every camera angle....WEAK! CAMERA: Learn to use it.<br /><br />Anyway, I'm running out of complaining space.....rent it - I dare you...Rent it and learn from it...give it a 1 rating..it deserves it.<br /><br />Signing off... Amanda Christmas"
# 1	"My all-time favorite movie! I have seen many movies, but this one beats them all! Excelent acting, wonderful story. You will, as a ""normal"" caring person start to love George. Altough he is an actor, he is also himself and a very lovable person. And maby most important thing: you will learn to respect & look different to people with Down Syndrome."
# 1	Wonderful film, one of the best horror films of the 70s. She is realistic settings and atmospheres. As usual it was inevitable the usual negative comments. I have noticed that most horror films of a certain period many times fail to reach even sufficiency. Obviously because most horror movies are old and must be denigrati, is like a mental mechanism that moves the minds of the potential of music critics here.<br /><br />Before you read the review already knew what was the final judgment. In the film a good gift because 10 is really well done. Raines reads quite well and the film as a way in which it was produced reminds me a lot of Kubrick films. He really impression. Excellent film really. I consider a film anthology of years'70.
# 0	and shot in Vancouver with the 'mountains' of the low country of South Carolina visible in the background. For heaven's sake, they should have reset the location. There are no coastal mountains in South Carolina. Period.<br /><br />Lame visuals. They should have been beautiful. And the story limped along.<br /><br />I really don't understand why it was such a hit as a book, although I have to admit it's one I haven't read as yet. Usually I read the book and give the film a miss. There was nothing in this movie that made me want to buy the book, or even borrow it from the library.<br /><br />Verdict: The Mermaid Chair seemed pretty shallow to moi.
# 1	This is the best dub I've ever heard by Disney, as well as the best adaptation since the biggest abuse ever on soundtrack, themes, characters, dialogues in Kiki Delivery Service. Urrrghhh<br /><br />This one has different atmosphere, especially the deviation from the common heroine. This one has both hero and heroine (although I don't really endorse the use of hero & heroine here, since Miyazaki is out from the stereotype & common theme). As usual, after being introduced by Spirited away, amazed by Mononoke, troubled by Grave of Fireflies, and deeply touched by Majo no Takkyuubin , this one start with a bit doubt in my part. Wondering if this will be the first Ghibi's dud. Well, in the end just like Only Yesterday and Whisper of the Heart, I ended up giving 10 rating. I'd give 9.8 rating, but the additional 0.2 is there to share the good feeling by encouraging people to see the movie.<br /><br />SPOILER Somehow I see this as a sad movie, people die in this one, the lonely robot, the abandoned place, and it ends with destruction. It is as if mankind really can't live with too much power. The collapsing scene gave me patches of Metropolis ending. It's just sad somehow. The plot is apparent in most reviews and the soundtrack rules as well (as always). Joe Hisaishi really belongs to Uematsu, Kanno, Williams caliber.People who can brings a movie, a game, an event to life, even to be a lingering moments by astounding composition.<br /><br />This is a feel good movie that used to be part of US cinema in the classic days (It's a Wonderful Life etc etc). Well, things change....
# 1	"Linking story: another first-time viewing for me and, again, this is one of the most popular of the Amicus anthologies - and it's easy to see why, though I realize how the film's rather meaningless title could be misleading for some; I certainly fancied director Peter Duffell's choice - DEATH AND THE MAIDEN (which, incidentally, is a classical piece by Schubert that is heard in the film during the Peter Cushing episode) - a great deal more. Though the linking device itself is not all that great, the episodes are all equally compelling and enjoyable. Production values come off as very respectable indeed for the budget Duffell had to work with. The latter infuses the film with a great deal of style which is not so common with this type of film and, frankly, it makes one regret the fact that he wished to distance himself from the genre (though more so as not to be typecast rather than because he felt it was beneath him).<br /><br />Now to the individual stories themselves: <br /><br />""Method For Murder"": the opening segment does not offer any real surprises but, to make up for this, it's quietly suspenseful and appropriately creepy at times (Tom Adams' 'fictitious' villain looking like the long-lost brother of Boris Karloff from THE OLD DARK HOUSE [1932]); also, it ends with a satisfactory DIABOLIQUE-type twist, and features a fairly intense role for Denholm Elliott in the lead. That's all we need out of it, really.<br /><br />""Waxworks"": for the second story we are introduced to a curiously romantic mood which is quite unusual for this type of film; Peter Cushing and Joss Ackland are both excellent (as well as impeccably dressed) in their roles of two jilted lovers of a woman who continues to obsess them even after such a long time, and whose friendly rivalry can only lead them blindly and inexorably to a fate that is literally worse than death; an ominous hallucination scene with Peter Cushing is quite well done in view of the limited resources at hand, and Ackland's inexplicable inability - or unwillingness - to leave town somewhat recalls the house-trapped aristocrats of Bunuel's THE EXTERMINATING ANGEL (1962).<br /><br />""Sweets To The Sweet"": this is perhaps the finest episode of all - with his ambiguous role here, Christopher Lee continues to demonstrate his versatility and he is matched by an understanding Nyree Dawn Porter and the deceptive innocence of Chloe Franks (who appears as Lee's daughter). The film's treatment of the occult here is both subtle and mature, culminating in a powerful and extremely chilling 'curtain'. Trivia Note: Chloe Franks appears as a grown-up in the featurette included on the disc, and when I saw her I felt an immediate familiarity with her face but couldn't quite put my finger on it. Later, on reading her filmography, it was revealed to me that she had played one of the leads in the long-running stage adaptation of Agatha Christie's ""The Mousetrap"" in London's West End, which my brother and I were fortunate enough to catch while we there on holiday in the Summer of 2002! Needless to say, we had no idea then that she had once created such a delicate - and delicious - portrayal in sheer evil, mainly by virtue of her peculiar look and a devilish smile!! <br /><br />""The Cloak"": a wacky but oddly reverent vampire tale (that still manages to debunk many of the myths attached to the subgenre, while inventing some new ones!) which takes in some wonderful digs at exploitation cinema and, at one point, Christopher Lee himself!; Jon Pertwee is marvelous as the campy horror star who gets more than he bargained for when he attempts to bring a measure of authenticity to his work; Ingrid Pitt sends up her image nicely though her role is somewhat subsidiary to the proceedings; Geoffrey Bayldon (made up to look like Ernest Thesiger) also has a memorably quirky bit; the 'silent-cinema' style of the ending was a pretty audacious one to pull on an audience, I suppose - and, while some of the humor ...

# %%
import pandas as pd

train_df = pd.read_csv("train.tsv", delimiter="\t")
test_df = pd.read_csv("test.tsv", delimiter="\t")

print('Train size = {}'.format(len(train_df)))
print('Test size = {}'.format(len(test_df)))
# Out:
# Train size = 25000
# Test size = 25000

# %%
train_df
# Out:
#        is_positive                                             review
# 0                0  Dreamgirls, despite its fistful of Tony wins i...
# 1                0  This show comes up with interesting locations ...
# 2                1  I simply love this movie. I also love the Ramo...
# 3                0  Spoilers ahead if you want to call them that.....
# 4                1  My all-time favorite movie! I have seen many m...
# ...            ...                                                ...
# 24995            1  I am a big fan of the movie, but not for the u...
# 24996            0  I'm not going to bother with a plot synopsis s...
# 24997            0  This movie . . . I don't know. Why they would ...
# 24998            1  Saw this film on DVD yesterday and was gob-sma...
# 24999            0  This was a disappointment - none of the nuance...
#
# [25000 rows x 2 columns]

# %%
import numpy as np

# %%
import re

# %%
from collections import Counter

# %%
df_neg=train_df[train_df.is_positive==0]
df_pos=train_df[train_df.is_positive==1]

# %%
cnt_neg = Counter(re.findall(r'\w+',str(df_neg.review.to_list())))
cnt_pos = Counter(re.findall(r'\w+',str(df_pos.review.to_list())))

# %%
cnt_neg.most_common()
# Out:
# [('the', 140173),
#  ('a', 76360),
#  ('and', 70515),
#  ('of', 68239),
#  ('to', 68045),
#  ('br', 52636),
#  ('is', 49501),
#  ('I', 44047),
#  ('in', 40857),
#  ('it', 39442),
#  ('that', 35949),
#  ('this', 33475),
#  ('s', 30397),
#  ('was', 26050),
#  ('movie', 24545),
#  ('The', 22495),
#  ('for', 20789),
#  ('with', 20360),
#  ('t', 20200),
#  ('as', 19081),
#  ('film', 19025),
#  ('but', 18052),
#  ('on', 16633),
#  ('you', 15810),
#  ('have', 15006),
#  ('not', 14747),
#  ('are', 14452),
#  ('be', 14428),
#  ('one', 12053),
#  ('his', 11586),
#  ('he', 11519),
#  ('at', 11368),
#  ('they', 11237),
#  ('all', 10940),
#  ('like', 10874),
#  ('by', 10179),
#  ('just', 9949),
#  ('an', 9928),
#  ('or', 9852),
#  ('so', 9831),
#  ('who', 9526),
#  ('from', 9317),
#  ('about', 8921),
#  ('out', 8887),
#  ('It', 8808),
#  ('some', 7658),
#  ('her', 7640),
#  ('has', 7537),
#  ('can', 7439),
#  ('This', 7260),
#  ('there', 7224),
#  ('good', 7150),
#  ('bad', 7013),
#  ('would', 6967),
#  ('no', 6935),
#  ('up', 6864),
#  ('even', 6710),
#  ('more', 6572),
#  ('if', 6458),
#  ('what', 6440),
#  ('only', 6433),
#  ('time', 6075),
#  ('had', 6042),
#  ('really', 6004),
#  ('were', 5954),
#  ('when', 5616),
#  ('which', 5598),
#  ('me', 5476),
#  ('very', 5466),
#  ('she', 5317),
#  ('see', 5288),
#  ('than', 5163),
#  ('their', 5133),
#  ('been', 5083),
#  ('story', 5050),
#  ('my', 5023),
#  ('much', 4928),
#  ('get', 4917),
#  ('do', 4770),
#  ('because', 4724),
#  ('make', 4650),
#  ('could', 4601),
#  ('people', 4554),
#  ('into', 4542),
#  ('made', 4501),
#  ('any', 4461),
#  ('don', 4398),
#  ('we', 4316),
#  ('them', 4151),
#  ('other', 4098),
#  ('plot', 4038),
#  ('movies', 3953),
#  ('too', 3933),
#  ('acting', 3928),
#  ('way', 3844),
#  ('how', 3839),
#  ('then', 3836),
#  ('him', 3834),
#  ('will', 3794),
#  ('first', 3696),
#  ('And', 3668),
#  ('But', 3662),
#  ('think', 3557),
#  ('There', 3555),
#  ('most', 3548),
#  ('characters', 3538),
#  ('off', 3537),
#  ('character', 3471),
#  ('watch', 3296),
#  ('better', 3295),
#  ('well', 3291),
#  ('being', 3283),
#  ('know', 3268),
#  ('seen', 3249),
#  ('did', 3243),
#  ('its', 3242),
#  ('over', 3238),
#  ('your', 3110),
#  ('ever', 3094),
#  ('never', 3069),
#  ('A', 3034),
#  ('after', 3031),
#  ('If', 3024),
#  ('films', 3015),
#  ('say', 2953),
#  ('also', 2939),
#  ('two', 2928),
#  ('where', 2924),
#  ('m', 2915),
#  ('little', 2896),
#  ('i', 2866),
#  ('should', 2863),
#  ('end', 2859),
#  ('ve', 2836),
#  ('something', 2823),
#  ('In', 2817),
#  ('thing', 2804),
#  ('scene', 2789),
#  ('scenes', 2754),
#  ('does', 2740),
#  ('show', 2740),
#  ('many', 2739),
#  ('here', 2667),
#  ('nothing', 2642),
#  ('didn', 2612),
#  ('re', 2595),
#  ('doesn', 2571),
#  ('go', 2552),
#  ('through', 2535),
#  ('watching', 2503),
#  ('great', 2491),
#  ('such', 2467),
#  ('why', 2410),
#  ('actors', 2397),
#  ('these', 2390),
#  ('back', 2324),
#  ('actually', 2316),
#  ('He', 2315),
#  ('life', 2314),
#  ('worst', 2292),
#  ('going', 2282),
#  ('funny', 2280),
#  ('director', 2174),
#  ('old', 2139),
#  ('few', 2126),
#  ('look', 2116),
#  ('minutes', 2102),
#  ('want', 2098),
#  ('those', 2070),
#  ('man', 2064),
#  ('real', 2059),
#  ('still', 2055),
#  ('script', 2046),
#  ('same', 2041),
#  ('pretty', 2030),
#  ('10', 2027),
#  ('work', 2017),
#  ('before', 2014),
#  ('least', 2004),
#  ('seems', 1988),
#  ('enough', 1980),
#  ('horror', 1979),
#  ('original', 1955),
#  ('2', 1949),
#  ('best', 1948),
#  ('another', 1942),
#  ('What', 1939),
#  ('though', 1937),
#  ('around', 1931),
#  ('love', 1930),
#  ('got', 1921),
#  ('down', 1912),
#  ('guy', 1877),
#  ('lot', 1849),
#  ('find', 1843),
#  ('while', 1826),
#  ('fact', 1825),
#  ('isn', 1817),
#  ('anything', 1813),
#  ('part', 1802),
#  ('point', 1799),
#  ('makes', 1792),
#  ('thought', 1782),
#  ('whole', 1753),
#  ('every', 1752),
#  ('They', 1748),
#  ('things', 1743),
#  ('again', 1727),
#  ('give', 1719),
#  ('gets', 1703),
#  ('years', 1699),
#  ('take', 1690),
#  ('long', 1683),
#  ('cast', 1671),
#  ('making', 1663),
#  ('You', 1648),
#  ('might', 1631),
#  ('interesting', 1617),
#  ('money', 1594),
#  ('far', 1571),
#  ('ll', 1550),
#  ('right', 1549),
#  ('So', 1539),
#  ('quite', 1532),
#  ('That', 1530),
#  ('As', 1528),
#  ('1', 1520),
#  ('reason', 1520),
#  ('action', 1518),
#  ('looks', 1501),
#  ('without', 1501),
#  ('kind', 1500),
#  ('almost', 1497),
#  ('now', 1497),
#  ('done', 1496),
#  ('must', 1476),
#  ('come', 1471),
#  ('wasn', 1470),
#  ('awful', 1467),
#  ('am', 1455),
#  ('trying', 1453),
#  ('big', 1448),
#  ('comedy', 1441),
#  ('saw', 1424),
#  ('d', 1423),
#  ('away', 1413),
#  ('boring', 1400),
#  ('looking', 1390),
#  ('believe', 1380),
#  ('poor', 1373),
#  ('times', 1373),
#  ('probably', 1370),
#  ('new', 1364),
#  ('girl', 1355),
#  ('us', 1353),
#  ('stupid', 1353),
#  ('between', 1351),
#  ('someone', 1346),
#  ('TV', 1341),
#  ('rather', 1332),
#  ('feel', 1331),
#  ('waste', 1331),
#  ('effects', 1331),
#  ('own', 1320),
#  ('may', 1318),
#  ('hard', 1310),
#  ('idea', 1305),
#  ('terrible', 1291),
#  ('half', 1290),
#  ('bit', 1289),
#  ('woman', 1285),
#  ('sense', 1285),
#  ('anyone', 1280),
#  ('found', 1267),
#  ('3', 1266),
#  ('last', 1249),
#  ('world', 1245),
#  ('book', 1242),
#  ('music', 1241),
#  ('goes', 1235),
#  ('put', 1235),
#  ('since', 1224),
#  ('series', 1221),
#  ('sure', 1217),
#  ('comes', 1215),
#  ('said', 1214),
#  ('role', 1213),
#  ('main', 1206),
#  ('else', 1193),
#  ('worse', 1183),
#  ('screen', 1176),
#  ('supposed', 1174),
#  ('audience', 1169),
#  ('young', 1167),
#  ('budget', 1163),
#  ('ending', 1162),
#  ('actor', 1161),
#  ('low', 1153),
#  ('Not', 1149),
#  ('set', 1145),
#  ('completely', 1145),
#  ('seem', 1143),
#  ('course', 1138),
#  ('watched', 1137),
#  ('place', 1133),
#  ('either', 1126),
#  ('left', 1125),
#  ('always', 1123),
#  ('having', 1116),
#  ('instead', 1113),
#  ('She', 1111),
#  ('mean', 1106),
#  ('family', 1104),
#  ('shot', 1096),
#  ('When', 1095),
#  ('For', 1090),
#  ('simply', 1087),
#  ('wrong', 1077),
#  ('both', 1057),
#  ('let', 1047),
#  ('less', 1043),
#  ('yet', 1042),
#  ('camera', 1040),
#  ('special', 1040),
#  ('read', 1039),
#  ('No', 1035),
#  ('year', 1024),
#  ('worth', 1021),
#  ('couldn', 1019),
#  ('One', 1012),
#  ('rest', 1009),
#  ('played', 1007),
#  ('DVD', 1007),
#  ('day', 1006),
#  ('We', 997),
#  ('sex', 995),
#  ('try', 992),
#  ('fun', 992),
#  ('three', 986),
#  ('everything', 981),
#  ('Why', 981),
#  ('version', 980),
#  ('However', 977),
#  ('production', 975),
#  ('video', 973),
#  ('performance', 964),
#  ('American', 963),
#  ('our', 962),
#  ('used', 962),
#  ('Even', 957),
#  ('high', 957),
#  ('play', 957),
#  ('horrible', 956),
#  ('All', 955),
#  ('line', 954),
#  ('Well', 953),
#  ('My', 950),
#  ('start', 948),
#  ('takes', 947),
#  ('mind', 947),
#  ('together', 947),
#  ('4', 946),
#  ('need', 937),
#  ('seeing', 937),
#  ('tell', 933),
#  ('wife', 931),
#  ('kids', 928),
#  ('himself', 925),
#  ('use', 922),
#  ('dialogue', 921),
#  ('doing', 920),
#  ('given', 912),
#  ('Then', 911),
#  ('lines', 911),
#  ('during', 904),
#  ('problem', 903),
#  ('Don', 900),
#  ('women', 899),
#  ('getting', 894),
#  ('couple', 892),
#  ('help', 891),
#  ('fan', 889),
#  ('each', 887),
#  ('name', 880),
#  ('different', 871),
#  ('especially', 870),
#  ('piece', 870),
#  ('maybe', 867),
#  ('crap', 862),
#  ('everyone', 858),
#  ('entire', 854),
#  ('seemed', 854),
#  ('head', 854),
#  ('shows', 853),
#  ('At', 849),
#  ('once', 848),
#  ('guess', 848),
#  ('second', 845),
#  ('John', 842),
#  ('person', 841),
#  ('plays', 835),
#  ('To', 833),
#  ('Hollywood', 832),
#  ('understand', 831),
#  ('short', 830),
#  ('nice', 830),
#  ('felt', 827),
#  ('sort', 821),
#  ('care', 820),
#  ('How', 817),
#  ('school', 811),
#  ('house', 809),
#  ('flick', 808),
#  ('written', 806),
#  ('night', 803),
#  ('itself', 802),
#  ('decent', 798),
#  ('title', 797),
#  ('death', 792),
#  ('later', 791),
#  ('tries', 787),
#  ('wanted', 787),
#  ('After', 786),
#  ('went', 786),
#  ('case', 786),
#  ('job', 786),
#  ('until', 784),
#  ('absolutely', 783),
#  ('face', 780),
#  ('5', 778),
#  ('called', 776),
#  ('annoying', 775),
#  ('laugh', 774),
#  ('black', 773),
#  ('home', 773),
#  ('ridiculous', 768),
#  ('dead', 767),
#  ('writing', 766),
#  ('friends', 766),
#  ('hour', 764),
#  ('came', 762),
#  ('true', 761),
#  ('killer', 759),
#  ('top', 758),
#  ('next', 758),
#  ('stars', 758),
#  ('however', 755),
#  ('won', 755),
#  ('playing', 754),
#  ('guys', 750),
#  ('already', 749),
#  ('keep', 732),
#  ('example', 732),
#  ('totally', 731),
#  ('attempt', 731),
#  ('along', 726),
#  ('moments', 725),
#  ('Oh', 725),
#  ('men', 723),
#  ('Now', 720),
#  ('full', 714),
#  ('THE', 713),
#  ('car', 712),
#  ('direction', 706),
#  ('star', 701),
#  ('thinking', 701),
#  ('act', 698),
#  ('quality', 695),
#  ('sound', 693),
#  ('turn', 689),
#  ('lack', 685),
#  ('truly', 682),
#  ('style', 681),
#  ('kill', 676),
#  ('although', 675),
#  ('gore', 673),
#  ('recommend', 669),
#  ('starts', 668),
#  ('lead', 668),
#  ('father', 667),
#  ('remember', 667),
#  ('looked', 666),
#  ('cheap', 665),
#  ('Also', 664),
#  ('wouldn', 662),
#  ('killed', 659),
#  ('etc', 658),
#  ('stuff', 657),
#  ('obvious', 654),
#  ('myself', 653),
#  ('enjoy', 653),
#  ('beginning', 652),
#  ('becomes', 651),
#  ('against', 650),
#  ('except', 650),
#  ('Just', 649),
#  ('save', 648),
#  ('lost', 648),
#  ('dull', 647),
#  ('OK', 646),
#  ('evil', 642),
#  ('kid', 641),
#  ('children', 641),
#  ('x96', 638),
#  ('small', 637),
#  ('happens', 635),
#  ('obviously', 634),
#  ('early', 633),
#  ('others', 631),
#  ('slow', 630),
#  ('hand', 630),
#  ('become', 626),
#  ('complete', 625),
#  ('under', 625),
#  ('Some', 623),
#  ('gave', 622),
#  ('episode', 622),
#  ('poorly', 621),
#  ('hope', 620),
#  ('classic', 619),
#  ('often', 617),
#  ('wonder', 616),
#  ('wants', 613),
#  ('predictable', 613),
#  ('lame', 613),
#  ('saying', 609),
#  ('self', 608),
#  ('based', 606),
#  ('run', 604),
#  ('girls', 604),
#  ('Mr', 604),
#  ('behind', 603),
#  ('boy', 601),
#  ('jokes', 600),
#  ('cannot', 599),
#  ('picture', 599),
#  ('friend', 599),
#  ('Unfortunately', 598),
#  ('several', 596),
#  ('First', 592),
#  ('certainly', 592),
#  ('close', 590),
#  ('writer', 590),
#  ('While', 589),
#  ('expect', 589),
#  ('liked', 588),
#  ('silly', 586),
#  ('mother', 583),
#  ('fans', 583),
#  ('entertaining', 583),
#  ('says', 581),
#  ('B', 579),
#  ('actress', 575),
#  ('happened', 575),
#  ('themselves', 575),
#  ('stop', 575),
#  ('cut', 573),
#  ('performances', 573),
#  ('blood', 572),
#  ('humor', 571),
#  ('involved', 569),
#  ('happen', 566),
#  ('bunch', 566),
#  ('human', 565),
#  ('group', 563),
#  ('disappointed', 563),
#  ('Of', 562),
#  ('hours', 561),
#  ('interest', 560),
#  ('beautiful', 560),
#  ('daughter', 558),
#  ('white', 557),
#  ('turns', 557),
#  ('viewer', 557),
#  ('cinema', 556),
#  ('yourself', 553),
#  ('heard', 552),
#  ('finally', 552),
#  ('shots', 551),
#  ('running', 550),
#  ('talking', 550),
#  ('child', 546),
#  ('live', 544),
#  ('gives', 544),
#  ('started', 543),
#  ('seriously', 542),
#  ('body', 542),
#  ('type', 541),
#  ('badly', 540),
#  ('fight', 539),
#  ('parts', 539),
#  ('word', 538),
#  ('His', 538),
#  ('mess', 536),
#  ('single', 535),
#  ('side', 534),
#  ('extremely', 534),
#  ('violence', 534),
#  ('call', 533),
#  ('directed', 533),
#  ('able', 533),
#  ('scary', 532),
#  ('Maybe', 532),
#  ('effort', 531),
#  ('voice', 530),
#  ('took', 530),
#  ('female', 529),
#  ('Michael', 527),
#  ('matter', 525),
#  ('aren', 525),
#  ('possible', 524),
#  ('drama', 522),
#  ('feeling', 522),
#  ('days', 520),
#  ('non', 520),
#  ('leave', 520),
#  ('hell', 519),
#  ('weak', 517),
#  ('sequel', 517),
#  ('turned', 517),
#  ('past', 515),
#  ('throughout', 513),
#  ('tried', 511),
#  ('son', 508),
#  ('genre', 508),
#  ('review', 508),
#  ('talent', 507),
#  ('none', 507),
#  ('perhaps', 506),
#  ('art', 506),
#  ('war', 506),
#  ('ends', 505),
#  ('town', 503),
#  ('hero', 503),
#  ('game', 502),
#  ('exactly', 500),
#  ('huge', 497),
#  ('On', 496),
#  ('moment', 492),
#  ('opening', 491),
#  ('dialog', 491),
#  ('eyes', 490),
#  ('serious', 490),
#  ('final', 488),
#  ('With', 485),
#  ('level', 484),
#  ('straight', 482),
#  ('taken', 482),
#  ('premise', 481),
#  ('fails', 481),
#  ('middle', 481),
#  ('coming', 479),
#  ('wasted', 479),
#  ('mention', 478),
#  ('editing', 478),
#  ('joke', 477),
#  ('particularly', 476),
#  ('apparently', 476),
#  ('minute', 476),
#  ('late', 473),
#  ('sad', 472),
#  ('lives', 472),
#  ('alone', 470),
#  ('stories', 469),
#  ('history', 468),
#  ('usually', 467),
#  ('New', 466),
#  ('across', 460),
#  ('definitely', 459),
#  ('falls', 459),
#  ('NOT', 458),
#  ('soon', 458),
#  ('clearly', 456),
#  ('rating', 454),
#  ('appears', 454),
#  ('five', 454),
#  ('career', 454),
#  ('told', 454),
#  ('hit', 453),
#  ('dumb', 453),
#  ('God', 453),
#  ('husband', 452),
#  ('storyline', 452),
#  ('known', 451),
#  ('fine', 450),
#  ('police', 449),
#  ('pointless', 448),
#  ('write', 447),
#  ('mostly', 445),
#  ('cool', 444),
#  ('chance', 443),
#  ('sit', 443),
#  ('taking', 441),
#  ('novel', 440),
#  ('major', 440),
#  ('despite', 437),
#  ('fast', 436),
#  ('English', 436),
#  ('material', 435),
#  ('room', 435),
#  ('Yes', 435),
#  ('basically', 434),
#  ('knew', 433),
#  ('rent', 432),
#  ('beyond', 432),
#  ('talk', 432),
#  ('actual', 430),
#  ('shown', 430),
#  ('kept', 430),
#  ('works', 427),
#  ('points', 426),
#  ('killing', 426),
#  ('ones', 426),
#  ('sorry', 425),
#  ('wish', 424),
#  ('local', 423),
#  ('ago', 422),
#  ('Lee', 422),
#  ('opinion', 421),
#  ('words', 421),
#  ('including', 420),
#  ('hate', 420),
#  ('problems', 420),
#  ('roles', 419),
#  ('decided', 418),
#  ('Who', 418),
#  ('dark', 417),
#  ('giving', 416),
#  ('theater', 415),
#  ('brother', 415),
#  ('order', 415),
#  ('number', 414),
#  ('experience', 414),
#  ('Man', 413),
#  ('stay', 413),
#  ('reviews', 412),
#  ('unless', 412),
#  ('usual', 411),
#  ('flat', 410),
#  ('using', 409),
#  ('feels', 409),
#  ('somewhat', 409),
#  ('ten', 408),
#  ('writers', 407),
#  ('Is', 407),
#  ('whose', 405),
#  ('strange', 403),
#  ('average', 402),
#  ('near', 402),
#  ('nudity', 402),
#  ('due', 402),
#  ('credits', 401),
#  ('easily', 400),
#  ('plain', 400),
#  ('20', 400),
#  ('knows', 399),
#  ('bring', 399),
#  ('possibly', 399),
#  ('total', 399),
#  ('James', 397),
#  ('change', 396),
#  ('needs', 392),
#  ('expected', 391),
#  ('bored', 390),
#  ('clear', 390),
#  ('die', 389),
#  ('IMDb', 389),
#  ('attention', 388),
#  ('cheesy', 388),
#  ('needed', 388),
#  ('score', 387),
#  ('nearly', 387),
#  ('cinematography', 386),
#  ('pathetic', 386),
#  ('sequence', 386),
#  ('released', 386),
#  ('anyway', 386),
#  ('class', 385),
#  ('figure', 385),
#  ('T', 385),
#  ('Or', 382),
#  ('sets', 382),
#  ('comments', 381),
#  ('excellent', 381),
#  ('From', 380),
#  ('Robert', 380),
#  ('monster', 380),
#  ('garbage', 379),
#  ('four', 379),
#  ('upon', 379),
#  ('song', 378),
#  ('doubt', 378),
#  ('potential', 378),
#  ('begin', 377),
#  ('somehow', 377),
#  ('entertainment', 377),
#  ('forced', 377),
#  ('age', 377),
#  ('sometimes', 376),
#  ('footage', 376),
#  ('development', 376),
#  ('documentary', 375),
#  ('living', 375),
#  ('laughable', 375),
#  ('remake', 375),
#  ('view', 374),
#  ('please', 374),
#  ('S', 373),
#  ('means', 373),
#  ('television', 372),
#  ('David', 372),
#  ('fall', 372),
#  ('stand', 371),
#  ('30', 371),
#  ('murder', 371),
#  ('thriller', 370),
#  ('songs', 369),
#  ('free', 369),
#  ('George', 369),
#  ('comic', 368),
#  ('add', 367),
#  ('above', 367),
#  ('forward', 366),
#  ('enjoyed', 366),
#  ('British', 366),
#  ('haven', 365),
#  ('nor', 364),
#  ('light', 364),
#  ('move', 364),
#  ('hear', 363),
#  ('Instead', 363),
#  ('fake', 363),
#  ('trash', 362),
#  ('Most', 362),
#  ('ask', 362),
#  ('Although', 360),
#  ('laughs', 360),
#  ('important', 360),
#  ('reality', 359),
#  ('message', 359),
#  ('avoid', 358),
#  ('whether', 358),
#  ('musical', 357),
#  ('directing', 356),
#  ('failed', 356),
#  ('similar', 355),
#  ('yes', 355),
#  ('question', 355),
#  ('finds', 355),
#  ('result', 354),
#  ('reading', 354),
#  ('heart', 354),
#  ('spent', 354),
#  ('gay', 354),
#  ('filmed', 354),
#  ('named', 354),
#  ('pay', 353),
#  ('suspense', 353),
#  ('King', 353),
#  ('events', 352),
#  ('Its', 352),
#  ('zombie', 352),
#  ('comment', 351),
#  ('By', 350),
#  ('buy', 349),
#  ('attempts', 349),
#  ('hilarious', 349),
#  ('Here', 348),
#  ('male', 347),
#  ('elements', 346),
#  ('country', 346),
#  ('weird', 346),
#  ('box', 346),
#  ('Richard', 346),
#  ('whatever', 346),
#  ('modern', 345),
#  ('90', 345),
#  ('Do', 345),
#  ('sequences', 345),
#  ('sexual', 345),
#  ('incredibly', 344),
#  ('within', 344),
#  ('D', 344),
#  ('girlfriend', 344),
#  ('cop', 341),
#  ('imagine', 341),
#  ('hardly', 340),
#  ('filmmakers', 340),
#  ('ideas', 339),
#  ('feature', 339),
#  ('showing', 339),
#  ('cover', 339),
#  ('Christmas', 337),
#  ('lots', 336),
#  ('meant', 336),
#  ('Let', 336),
#  ('wait', 336),
#  ('gone', 336),
#  ('worked', 336),
#  ('sounds', 335),
#  ('appear', 335),
#  ('Like', 334),
#  ('excuse', 334),
#  ('shame', 334),
#  ('Dr', 334),
#  ('zombies', 333),
#  ('screenplay', 333),
#  ('typical', 332),
#  ('follow', 332),
#  ('80', 332),
#  ('unfortunately', 332),
#  ('These', 331),
#  ('realize', 330),
#  ('overall', 330),
#  ('villain', 329),
#  ('hot', 329),
#  ('unbelievable', 329),
#  ('oh', 328),
#  ('viewers', 327),
#  ('positive', 327),
#  ('herself', 326),
#  ('theme', 326),
#  ('wrote', 326),
#  ('barely', 326),
#  ('acted', 326),
#  ('working', 325),
#  ('tells', 325),
#  ('sister', 325),
#  ('weren', 325),
#  ('release', 324),
#  ('producers', 323),
#  ('leads', 323),
#  ('twist', 323),
#  ('makers', 323),
#  ('An', 322),
#  ('perfect', 322),
#  ('subject', 321),
#  ('loved', 321),
#  ('slasher', 321),
#  ('quickly', 320),
#  ('admit', 319),
#  ('happy', 319),
#  ('15', 318),
#  ('kills', 318),
#  ('Tom', 317),
#  ('check', 316),
#  ('value', 315),
#  ('disappointing', 315),
#  ('disappointment', 315),
#  ('learn', 314),
#  ('crazy', 314),
#  ('nowhere', 313),
#  ('directors', 313),
#  ('Peter', 313),
#  ('team', 312),
#  ('third', 311),
#  ('form', 311),
#  ('open', 311),
#  ('bother', 311),
#  ('relationship', 310),
#  ('certain', 309),
#  ('concept', 308),
#  ('surprised', 308),
#  ('period', 308),
#  ('expecting', 308),
#  ('previous', 308),
#  ('ways', 308),
#  ('walk', 307),
#  ('strong', 306),
#  ('missing', 305),
#  ('soundtrack', 305),
#  ('leaves', 304),
#  ('Movie', 304),
#  ('ended', 304),
#  ('simple', 304),
#  ('list', 303),
#  ('eye', 303),
#  ('Another', 302),
#  ('effect', 302),
#  ('power', 302),
#  ('fighting', 302),
#  ('creepy', 302),
#  ('mystery', 302),
#  ('accent', 302),
#  ('front', 302),
#  ('space', 301),
#  ('difficult', 301),
#  ('America', 301),
#  ('spend', 301),
#  ('Dead', 300),
#  ('6', 300),
#  ('break', 300),
#  ('casting', 298),
#  ('painful', 298),
#  ('redeeming', 297),
#  ('forget', 297),
#  ('Paul', 296),
#  ('rate', 296),
#  ('Japanese', 295),
#  ('hands', 294),
#  ...]

# %%
cnt_pos.most_common()
# Out:
# [('the', 149990),
#  ('and', 86462),
#  ('a', 80141),
#  ('of', 75899),
#  ('to', 65948),
#  ('is', 56762),
#  ('br', 49234),
#  ('in', 46980),
#  ('it', 38353),
#  ('I', 38076),
#  ('that', 34427),
#  ('s', 32420),
#  ('this', 27325),
#  ('as', 24494),
#  ('with', 22564),
#  ('The', 22555),
#  ('was', 21791),
#  ('for', 21420),
#  ('film', 20664),
#  ('movie', 18816),
#  ('but', 17099),
#  ('on', 16428),
#  ('his', 16327),
#  ('you', 14979),
#  ('are', 14686),
#  ('t', 13559),
#  ('he', 13229),
#  ('not', 13213),
#  ('have', 12485),
#  ('one', 12360),
#  ('be', 12316),
#  ('by', 11656),
#  ('who', 11119),
#  ('an', 10870),
#  ('all', 10773),
#  ('at', 10455),
#  ('from', 10315),
#  ('her', 10003),
#  ('It', 9622),
#  ('has', 9146),
#  ('like', 8625),
#  ('they', 8423),
#  ('about', 8210),
#  ('out', 8021),
#  ('so', 7994),
#  ('very', 7941),
#  ('This', 7673),
#  ('or', 7490),
#  ('more', 7399),
#  ('good', 7346),
#  ('can', 6859),
#  ('some', 6794),
#  ('just', 6658),
#  ('story', 6517),
#  ('time', 6363),
#  ('what', 6337),
#  ('up', 6220),
#  ('which', 6124),
#  ('she', 6117),
#  ('when', 6088),
#  ('their', 5921),
#  ('great', 5912),
#  ('see', 5812),
#  ('well', 5806),
#  ('there', 5404),
#  ('would', 5340),
#  ('really', 5333),
#  ('my', 5284),
#  ('had', 5068),
#  ('him', 4986),
#  ('will', 4979),
#  ('me', 4960),
#  ('only', 4944),
#  ('if', 4920),
#  ('also', 4837),
#  ('were', 4752),
#  ('than', 4718),
#  ('other', 4676),
#  ('much', 4532),
#  ('into', 4525),
#  ('most', 4514),
#  ('we', 4449),
#  ('first', 4374),
#  ('even', 4303),
#  ('people', 4237),
#  ('its', 4199),
#  ('been', 4179),
#  ('get', 4171),
#  ('love', 3973),
#  ('way', 3952),
#  ('life', 3951),
#  ('no', 3934),
#  ('best', 3910),
#  ('because', 3870),
#  ('them', 3797),
#  ('how', 3771),
#  ('made', 3752),
#  ('films', 3743),
#  ('do', 3730),
#  ('But', 3676),
#  ('think', 3586),
#  ('A', 3569),
#  ('many', 3525),
#  ('too', 3524),
#  ('characters', 3511),
#  ('movies', 3493),
#  ('two', 3492),
#  ('character', 3487),
#  ('seen', 3384),
#  ('show', 3251),
#  ('make', 3234),
#  ('could', 3171),
#  ('watch', 3155),
#  ('In', 3144),
#  ('little', 3129),
#  ('And', 3128),
#  ('being', 3098),
#  ('never', 3083),
#  ('He', 3040),
#  ('still', 3024),
#  ('after', 3008),
#  ('where', 2998),
#  ('don', 2984),
#  ('does', 2980),
#  ('over', 2892),
#  ('any', 2886),
#  ('then', 2871),
#  ('man', 2870),
#  ('know', 2807),
#  ('did', 2700),
#  ('years', 2692),
#  ('i', 2678),
#  ('There', 2650),
#  ('ever', 2643),
#  ('end', 2631),
#  ('scene', 2554),
#  ('such', 2493),
#  ('real', 2471),
#  ('back', 2439),
#  ('off', 2437),
#  ('here', 2409),
#  ('scenes', 2407),
#  ('plot', 2400),
#  ('say', 2398),
#  ('acting', 2376),
#  ('makes', 2365),
#  ('your', 2348),
#  ('If', 2343),
#  ('better', 2336),
#  ('10', 2324),
#  ('through', 2323),
#  ('work', 2321),
#  ('those', 2316),
#  ('ve', 2314),
#  ('these', 2313),
#  ('go', 2256),
#  ('find', 2256),
#  ('old', 2161),
#  ('though', 2161),
#  ('cast', 2116),
#  ('young', 2099),
#  ('quite', 2094),
#  ('should', 2084),
#  ('series', 2077),
#  ('while', 2075),
#  ('lot', 2061),
#  ('something', 2061),
#  ('world', 2056),
#  ('again', 2036),
#  ('always', 2022),
#  ('actors', 2016),
#  ('own', 2006),
#  ('between', 1996),
#  ('part', 1988),
#  ('both', 1973),
#  ('before', 1970),
#  ('role', 1964),
#  ('same', 1942),
#  ('family', 1941),
#  ('performance', 1924),
#  ('doesn', 1923),
#  ('m', 1893),
#  ('funny', 1892),
#  ('few', 1880),
#  ('us', 1877),
#  ('re', 1864),
#  ('watching', 1855),
#  ('may', 1824),
#  ('now', 1812),
#  ('bad', 1811),
#  ('look', 1799),
#  ('As', 1799),
#  ('another', 1760),
#  ('things', 1759),
#  ('times', 1758),
#  ('bit', 1753),
#  ('going', 1745),
#  ('every', 1737),
#  ('action', 1736),
#  ('director', 1726),
#  ('new', 1698),
#  ('down', 1695),
#  ('actually', 1690),
#  ('fact', 1679),
#  ('must', 1676),
#  ('didn', 1664),
#  ('comedy', 1657),
#  ('She', 1654),
#  ('fun', 1644),
#  ('You', 1643),
#  ('around', 1642),
#  ('saw', 1639),
#  ('thought', 1631),
#  ('right', 1626),
#  ('music', 1623),
#  ('take', 1617),
#  ('thing', 1610),
#  ('long', 1595),
#  ('feel', 1582),
#  ('got', 1582),
#  ('seems', 1580),
#  ('done', 1570),
#  ('played', 1554),
#  ('excellent', 1549),
#  ('want', 1540),
#  ('why', 1530),
#  ('without', 1530),
#  ('come', 1509),
#  ('beautiful', 1507),
#  ('each', 1506),
#  ('big', 1496),
#  ('almost', 1495),
#  ('pretty', 1492),
#  ('give', 1489),
#  ('different', 1489),
#  ('gets', 1484),
#  ('They', 1464),
#  ('especially', 1463),
#  ('interesting', 1456),
#  ('job', 1455),
#  ('enough', 1438),
#  ('shows', 1430),
#  ('last', 1398),
#  ('true', 1384),
#  ('plays', 1373),
#  ('day', 1370),
#  ('What', 1368),
#  ('When', 1363),
#  ('TV', 1356),
#  ('woman', 1353),
#  ('original', 1353),
#  ('since', 1349),
#  ('course', 1348),
#  ('our', 1337),
#  ('John', 1335),
#  ('father', 1325),
#  ('ll', 1322),
#  ('probably', 1313),
#  ('isn', 1312),
#  ('far', 1308),
#  ('DVD', 1307),
#  ('whole', 1305),
#  ('found', 1304),
#  ('horror', 1302),
#  ('point', 1298),
#  ('screen', 1296),
#  ('yet', 1294),
#  ('wonderful', 1279),
#  ('rather', 1272),
#  ('One', 1270),
#  ('away', 1266),
#  ('girl', 1260),
#  ('might', 1251),
#  ('comes', 1247),
#  ('am', 1241),
#  ('together', 1236),
#  ('making', 1235),
#  ('takes', 1231),
#  ('year', 1230),
#  ('hard', 1226),
#  ('performances', 1226),
#  ('himself', 1223),
#  ('American', 1223),
#  ('place', 1221),
#  ('kind', 1219),
#  ('play', 1217),
#  ('set', 1197),
#  ('perfect', 1187),
#  ('wife', 1183),
#  ('later', 1183),
#  ('goes', 1168),
#  ('version', 1163),
#  ('My', 1162),
#  ('ending', 1158),
#  ('That', 1154),
#  ('worth', 1144),
#  ('actor', 1127),
#  ('classic', 1124),
#  ('nothing', 1124),
#  ('So', 1108),
#  ('All', 1098),
#  ('least', 1097),
#  ('put', 1085),
#  ('having', 1083),
#  ('watched', 1082),
#  ('anyone', 1081),
#  ('book', 1079),
#  ('nice', 1071),
#  ('three', 1070),
#  ('We', 1069),
#  ('once', 1067),
#  ('enjoy', 1061),
#  ('seeing', 1055),
#  ('sure', 1051),
#  ('everyone', 1050),
#  ('anything', 1047),
#  ('d', 1044),
#  ('believe', 1042),
#  ('Hollywood', 1035),
#  ('gives', 1028),
#  ('seem', 1028),
#  ('during', 1023),
#  ('main', 1014),
#  ('audience', 1013),
#  ('looking', 1010),
#  ('loved', 1006),
#  ('fan', 1001),
#  ('However', 1000),
#  ('sense', 996),
#  ('amazing', 992),
#  ('everything', 991),
#  ('recommend', 989),
#  ('guy', 983),
#  ('help', 981),
#  ('episode', 979),
#  ('top', 978),
#  ('mind', 974),
#  ('trying', 973),
#  ('truly', 972),
#  ('short', 972),
#  ('For', 966),
#  ('special', 963),
#  ('said', 962),
#  ('small', 958),
#  ('home', 953),
#  ('script', 949),
#  ('2', 946),
#  ('human', 942),
#  ('favorite', 938),
#  ('high', 929),
#  ('often', 929),
#  ('definitely', 928),
#  ('moments', 926),
#  ('friends', 924),
#  ('men', 924),
#  ('liked', 917),
#  ('left', 915),
#  ('become', 915),
#  ('second', 911),
#  ('remember', 911),
#  ('until', 910),
#  ('won', 906),
#  ('used', 905),
#  ('war', 897),
#  ('less', 897),
#  ('style', 894),
#  ('others', 890),
#  ('along', 889),
#  ('today', 889),
#  ('shot', 887),
#  ('although', 883),
#  ('His', 883),
#  ('lives', 880),
#  ('early', 879),
#  ('heart', 878),
#  ('live', 877),
#  ('came', 877),
#  ('full', 872),
#  ('looks', 872),
#  ('enjoyed', 869),
#  ('brilliant', 856),
#  ('Not', 855),
#  ('use', 853),
#  ('read', 846),
#  ('works', 845),
#  ('entertaining', 844),
#  ('effects', 844),
#  ('drama', 844),
#  ('stars', 841),
#  ('playing', 841),
#  ('need', 839),
#  ('death', 838),
#  ('fine', 838),
#  ('house', 835),
#  ('night', 828),
#  ('given', 826),
#  ('While', 824),
#  ('wasn', 820),
#  ('minutes', 818),
#  ('women', 814),
#  ('Mr', 813),
#  ('kids', 808),
#  ('understand', 807),
#  ('cinema', 804),
#  ('keep', 803),
#  ('Michael', 802),
#  ('mother', 800),
#  ('someone', 800),
#  ('line', 798),
#  ('children', 795),
#  ('against', 793),
#  ('however', 792),
#  ('else', 792),
#  ('simply', 791),
#  ('reason', 788),
#  ('friend', 787),
#  ('star', 786),
#  ('After', 782),
#  ('next', 780),
#  ('couple', 779),
#  ('history', 775),
#  ('son', 773),
#  ('rest', 767),
#  ('face', 765),
#  ('certainly', 762),
#  ('picture', 762),
#  ('boy', 761),
#  ('fans', 759),
#  ('THE', 758),
#  ('itself', 758),
#  ('production', 757),
#  ('New', 753),
#  ('try', 753),
#  ('tell', 747),
#  ('black', 747),
#  ('let', 746),
#  ('start', 742),
#  ('person', 740),
#  ('Of', 740),
#  ('past', 740),
#  ('At', 738),
#  ('genre', 735),
#  ('half', 731),
#  ('several', 730),
#  ('throughout', 730),
#  ('To', 729),
#  ('humor', 727),
#  ('written', 726),
#  ('idea', 723),
#  ('highly', 723),
#  ('beginning', 722),
#  ('strong', 722),
#  ('becomes', 722),
#  ('able', 721),
#  ('based', 714),
#  ('completely', 712),
#  ('school', 711),
#  ('Also', 707),
#  ('1', 707),
#  ('x96', 703),
#  ('camera', 702),
#  ('town', 701),
#  ('money', 700),
#  ('late', 696),
#  ('getting', 694),
#  ('viewer', 693),
#  ('game', 692),
#  ('roles', 690),
#  ('felt', 689),
#  ('hope', 686),
#  ('final', 685),
#  ('side', 683),
#  ('case', 679),
#  ('stories', 676),
#  ('wants', 668),
#  ('doing', 667),
#  ('art', 666),
#  ('finally', 664),
#  ('under', 664),
#  ('With', 664),
#  ('turns', 663),
#  ('dark', 662),
#  ('lost', 659),
#  ('went', 659),
#  ('Even', 659),
#  ('James', 657),
#  ('name', 656),
#  ('simple', 655),
#  ('relationship', 655),
#  ('child', 655),
#  ('perhaps', 652),
#  ('7', 652),
#  ('either', 651),
#  ('budget', 651),
#  ('David', 651),
#  ('episodes', 648),
#  ('piece', 646),
#  ('maybe', 643),
#  ('wrong', 643),
#  ('8', 642),
#  ('days', 642),
#  ('3', 641),
#  ('Some', 640),
#  ('experience', 638),
#  ('sometimes', 635),
#  ('video', 634),
#  ('parts', 633),
#  ('turn', 630),
#  ('called', 629),
#  ('lines', 625),
#  ('5', 624),
#  ('head', 624),
#  ('known', 622),
#  ('close', 621),
#  ('sort', 621),
#  ('title', 619),
#  ('lead', 619),
#  ('example', 619),
#  ('including', 618),
#  ('Although', 617),
#  ('fantastic', 616),
#  ('Oscar', 615),
#  ('feeling', 612),
#  ('already', 611),
#  ('ago', 609),
#  ('themselves', 608),
#  ('score', 608),
#  ('musical', 608),
#  ('direction', 606),
#  ('absolutely', 605),
#  ('No', 605),
#  ('moment', 605),
#  ('behind', 604),
#  ('hit', 604),
#  ('age', 603),
#  ('sex', 602),
#  ('white', 601),
#  ('eyes', 599),
#  ('voice', 599),
#  ('Well', 597),
#  ('low', 597),
#  ('dialogue', 595),
#  ('soon', 592),
#  ('Paul', 592),
#  ('entire', 592),
#  ('finds', 590),
#  ('brother', 589),
#  ('quality', 588),
#  ('told', 588),
#  ('directed', 588),
#  ('reality', 587),
#  ('gave', 586),
#  ('hilarious', 585),
#  ('moving', 584),
#  ('hand', 583),
#  ('Jack', 583),
#  ('matter', 582),
#  ('laugh', 581),
#  ('chance', 581),
#  ('actress', 580),
#  ('future', 577),
#  ('whose', 575),
#  ('released', 572),
#  ('expect', 572),
#  ('evil', 570),
#  ('light', 570),
#  ('type', 568),
#  ('supporting', 568),
#  ('Robert', 566),
#  ('husband', 565),
#  ('took', 564),
#  ('murder', 564),
#  ('enjoyable', 561),
#  ('shown', 561),
#  ('number', 560),
#  ('self', 559),
#  ('view', 558),
#  ('happy', 558),
#  ('particularly', 556),
#  ('important', 555),
#  ('mean', 555),
#  ('change', 553),
#  ('tells', 553),
#  ('romantic', 552),
#  ('daughter', 551),
#  ('documentary', 551),
#  ('song', 550),
#  ('cinematography', 550),
#  ('heard', 549),
#  ('superb', 549),
#  ('career', 548),
#  ('etc', 546),
#  ('events', 546),
#  ('fight', 546),
#  ('dead', 546),
#  ('somewhat', 545),
#  ('wanted', 545),
#  ('sound', 543),
#  ('living', 543),
#  ('modern', 542),
#  ('starts', 542),
#  ('9', 541),
#  ('On', 531),
#  ('coming', 530),
#  ('opinion', 529),
#  ('English', 529),
#  ('instead', 527),
#  ('usual', 526),
#  ('Now', 524),
#  ('British', 524),
#  ('tale', 523),
#  ('says', 522),
#  ('Man', 522),
#  ('realistic', 520),
#  ('totally', 518),
#  ('violence', 517),
#  ('songs', 516),
#  ('greatest', 516),
#  ('animation', 515),
#  ('novel', 512),
#  ('care', 512),
#  ('country', 511),
#  ('ones', 510),
#  ('problem', 509),
#  ('girls', 509),
#  ('easy', 508),
#  ('leave', 508),
#  ('writing', 508),
#  ('York', 508),
#  ('involved', 508),
#  ('comic', 507),
#  ('thriller', 507),
#  ('attention', 506),
#  ('seemed', 504),
#  ('guys', 503),
#  ('run', 503),
#  ('extremely', 496),
#  ('alone', 496),
#  ('Richard', 493),
#  ('atmosphere', 491),
#  ('stuff', 491),
#  ('killer', 490),
#  ('ways', 489),
#  ('sequence', 489),
#  ('despite', 487),
#  ('surprised', 487),
#  ('television', 486),
#  ('perfectly', 486),
#  ('power', 485),
#  ('herself', 485),
#  ('act', 484),
#  ('tries', 484),
#  ('taken', 484),
#  ('George', 483),
#  ('similar', 483),
#  ('cannot', 483),
#  ('Then', 481),
#  ('begins', 480),
#  ('car', 479),
#  ('powerful', 478),
#  ('serious', 478),
#  ('myself', 478),
#  ('across', 477),
#  ('hero', 476),
#  ('sad', 476),
#  ('Just', 476),
#  ('Don', 476),
#  ('interest', 472),
#  ('writer', 472),
#  ('theme', 471),
#  ('unique', 471),
#  ('happened', 471),
#  ('order', 469),
#  ('knows', 469),
#  ('release', 468),
#  ('happen', 468),
#  ('slow', 468),
#  ('wish', 467),
#  ('level', 466),
#  ('police', 466),
#  ('famous', 465),
#  ('Her', 465),
#  ('memorable', 465),
#  ('group', 463),
#  ('due', 463),
#  ('class', 462),
#  ('sets', 460),
#  ('French', 460),
#  ('viewing', 459),
#  ('exactly', 458),
#  ('taking', 458),
#  ('message', 457),
#  ('opening', 456),
#  ('believable', 456),
#  ('problems', 456),
#  ('team', 455),
#  ('brought', 454),
#  ('nature', 453),
#  ('easily', 453),
#  ('couldn', 452),
#  ('thinking', 452),
#  ('season', 452),
#  ('working', 452),
#  ('cool', 452),
#  ('entertainment', 451),
#  ('knew', 450),
#  ('city', 450),
#  ('form', 450),
#  ('Disney', 449),
#  ('Peter', 448),
#  ('kid', 448),
#  ('stop', 448),
#  ('ends', 447),
#  ('soundtrack', 445),
#  ('among', 445),
#  ('local', 445),
#  ('meets', 444),
#  ('emotional', 443),
#  ('overall', 443),
#  ('bring', 442),
#  ('viewers', 442),
#  ('happens', 441),
#  ('room', 440),
#  ('needs', 437),
#  ('King', 437),
#  ('Tom', 436),
#  ('parents', 436),
#  ('within', 436),
#  ('beauty', 436),
#  ('crime', 436),
#  ('particular', 436),
#  ('strange', 436),
#  ('Great', 436),
#  ('killed', 435),
#  ('flick', 435),
#  ('mostly', 435),
#  ('From', 433),
#  ('How', 432),
#  ('4', 432),
#  ('B', 431),
#  ('society', 431),
#  ('masterpiece', 431),
#  ('period', 430),
#  ('elements', 430),
#  ('certain', 429),
#  ('feature', 428),
#  ('above', 428),
#  ('stand', 427),
#  ('named', 427),
#  ('four', 427),
#  ('Jane', 426),
#  ('typical', 426),
#  ('possible', 424),
#  ('brings', 423),
#  ('sister', 423),
#  ('follow', 421),
#  ('America', 421),
#  ('haven', 421),
#  ('usually', 420),
#  ('words', 419),
#  ('eye', 419),
#  ('showing', 419),
#  ('leads', 417),
#  ('An', 416),
#  ('started', 416),
#  ('talent', 415),
#  ('Japanese', 415),
#  ('stage', 413),
#  ('S', 411),
#  ('deal', 409),
#  ('yourself', 408),
#  ('became', 408),
#  ('middle', 408),
#  ('dance', 407),
#  ('guess', 407),
#  ('upon', 405),
#  ('turned', 405),
#  ('personal', 404),
#  ('surprise', 404),
#  ('War', 404),
#  ('giving', 402),
#  ('O', 402),
#  ('obvious', 402),
#  ('Like', 402),
#  ('romance', 400),
#  ('hours', 400),
#  ('major', 398),
#  ('kill', 398),
#  ('female', 397),
#  ('huge', 396),
#  ('learn', 395),
#  ('fantasy', 393),
#  ('feels', 393),
#  ('keeps', 392),
#  ('near', 391),
#  ('nearly', 391),
#  ('mystery', 391),
#  ('William', 390),
#  ('Tony', 390),
#  ('older', 389),
#  ('poor', 388),
#  ('Yes', 388),
#  ('difficult', 388),
#  ('means', 388),
#  ('clear', 388),
#  ('complete', 387),
#  ('Joe', 386),
#  ('shots', 386),
#  ('Stewart', 386),
#  ('era', 386),
#  ('incredible', 385),
#  ('appears', 384),
#  ('Best', 384),
#  ('situation', 383),
#  ('hour', 383),
#  ('subject', 382),
#  ('body', 381),
#  ('Overall', 381),
#  ('deep', 381),
#  ('points', 381),
#  ('sequences', 380),
#  ('Lee', 379),
#  ('dramatic', 379),
#  ('earlier', 379),
#  ('present', 379),
#  ('Its', 379),
#  ('comments', 377),
#  ('These', 377),
#  ('talking', 377),
#  ('truth', 375),
#  ('clearly', 375),
#  ('portrayal', 374),
#  ('fast', 374),
#  ('leaves', 373),
#  ('meet', 372),
#  ('fall', 371),
#  ('running', 370),
#  ('wonder', 370),
#  ('whether', 370),
#  ('business', 368),
#  ('figure', 368),
#  ('obviously', 367),
#  ('First', 367),
#  ('single', 366),
#  ('doubt', 365),
#  ('falls', 365),
#  ('filmed', 365),
#  ('hear', 364),
#  ('whom', 364),
#  ('World', 363),
#  ('jokes', 363),
#  ('sweet', 362),
#  ('dream', 361),
#  ('sexual', 360),
#  ('political', 360),
#  ('success', 359),
#  ('except', 359),
#  ('non', 359),
#  ('cut', 359),
#  ('setting', 359),
#  ('God', 358),
#  ('suspense', 358),
#  ('lack', 357),
#  ('word', 356),
#  ('touching', 356),
#  ('wouldn', 356),
#  ('sees', 354),
#  ('features', 353),
#  ('interested', 353),
#  ('actual', 352),
#  ('solid', 351),
#  ('beautifully', 351),
#  ('scary', 349),
#  ('buy', 348),
#  ('social', 348),
#  ('various', 347),
#  ('disappointed', 347),
#  ('match', 346),
#  ('plenty', 346),
#  ('battle', 346),
#  ('talk', 345),
#  ('Good', 345),
#  ('portrayed', 344),
#  ('move', 343),
#  ('recently', 342),
#  ('using', 342),
#  ('married', 342),
#  ('terrific', 342),
#  ('Most', 342),
#  ('miss', 342),
#  ('Kelly', 342),
#  ('Dr', 341),
#  ('five', 341),
#  ('aren', 340),
#  ('effective', 339),
#  ('beyond', 339),
#  ('Smith', 339),
#  ('lots', 338),
#  ('awesome', 338),
#  ('indeed', 337),
#  ('looked', 337),
#  ('manages', 336),
#  ('leading', 336),
#  ('caught', 335),
#  ('appreciate', 335),
#  ('towards', 335),
#  ('decent', 334),
#  ('third', 334),
#  ('call', 334),
#  ('ten', 334),
#  ('note', 333),
#  ('rare', 333),
#  ('storyline', 333),
#  ('moves', 332),
#  ('background', 332),
#  ('By', 331),
#  ('mention', 331),
#  ('gone', 331),
#  ('Mary', 330),
#  ('deserves', 329),
#  ('acted', 329),
#  ('eventually', 329),
#  ('familiar', 329),
#  ('directors', 329),
#  ('City', 329),
#  ('popular', 328),
#  ('Who', 328),
#  ('supposed', 328),
#  ('subtle', 327),
#  ('animated', 327),
#  ('Bill', 327),
#  ('boring', 327),
#  ('Star', 327),
#  ('Harry', 327),
#  ('theater', 326),
#  ('charming', 326),
#  ('forget', 326),
#  ('creepy', 325),
#  ('effect', 325),
#  ('hate', 325),
#  ('realize', 324),
#  ('adventure', 324),
#  ('Here', 324),
#  ('pace', 324),
#  ('impressive', 323),
#  ('Ben', 323),
#  ('open', 322),
#  ('Scott', 322),
#  ('Jim', 322),
#  ('material', 320),
#  ('rate', 320),
#  ('screenplay', 320),
#  ('noir', 320),
#  ('outstanding', 319),
#  ('yes', 319),
#  ('question', 319),
#  ('uses', 318),
#  ('telling', 317),
#  ('inside', 316),
#  ('create', 316),
#  ('created', 315),
#  ('dancing', 315),
#  ('visual', 315),
#  ('copy', 315),
#  ('kept', 315),
#  ('Director', 314),
#  ('attempt', 314),
#  ('intelligent', 314),
#  ('saying', 314),
#  ('Though', 313),
#  ('general', 313),
#  ('previous', 313),
#  ('blood', 312),
#  ('Is', 312),
#  ('rich', 312),
#  ('natural', 311),
#  ('add', 311),
#  ('expected', 311),
#  ('singing', 310),
#  ('language', 310),
#  ('Another', 310),
#  ('quickly', 309),
#  ('review', 308),
#  ('successful', 308),
#  ('stunning', 308),
#  ('straight', 307),
#  ('hands', 305),
#  ('adult', 305),
#  ('follows', 305),
#  ('rating', 304),
#  ('reasons', 304),
#  ('male', 304),
#  ('Why', 304),
#  ('themes', 303),
#  ('complex', 303),
#  ('admit', 301),
#  ('reviews', 300),
#  ('members', 300),
#  ('genius', 300),
#  ('images', 300),
#  ...]

# %% [markdown]
# Посмотрите глазами на тексты? Какие есть зацепки, как определить, что это за сентимент?
#
# Самое простое, как всегда - найти ключевые слова.

# %%
#@title Начинаем классифицировать! { vertical-output: true, display-mode: "form" }
positive_words = 'love','amazing','great','enjoy', 'best', 'wonderful' #@param {type:"raw"}
negative_words = 'worst','worse','trash','boring', 'bad','awful', '1/10', 'crap' #@param {type:"raw"}

positives_count = test_df.review.apply(lambda text: sum(word in text for word in positive_words))
negatives_count = test_df.review.apply(lambda text: sum(word in text for word in negative_words))
is_positive = positives_count > negatives_count
correct_count = (is_positive == test_df.is_positive).values.sum()

accuracy = correct_count / len(test_df)

print('Test accuracy = {:.2%}'.format(accuracy))
if accuracy > 0.71:
    from IPython.display import Image, display
    display(Image('https://s3.amazonaws.com/achgen360/t/rmmoZsub.png', width=500))
# Out:
# Test accuracy = 71.31%
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py:364: FormatterWarning: image/png formatter returned invalid type <class 'tuple'> (expected (<class 'bytes'>, <class 'str'>)) for object: <IPython.core.display.Image object>
#   FormatterWarning

# %% [markdown]
# **Задание** Придумайте хорошие ключевые слова или фразы и наберите хотя бы 71% точности на тесте (и не забудьте посмотреть на код классификации!)

# %% [markdown]
# **Задание** Кому-нибудь нравятся эти `<br /><br />`? Лично мне - нет. Напишите регулярку, которая будет их удалять

# %%
import re

pattern = re.compile('<br />')

print(train_df['review'].iloc[3])
print(pattern.subn(' ', train_df['review'].iloc[3])[0])
# Out:
# Spoilers ahead if you want to call them that...<br /><br />I would almost recommend this film just so people can truly see a 1/10. Where to begin, we'll start from the top...<br /><br />THE STORY: Don't believe the premise - the movie has nothing to do with abandoned cars, and people finially understanding what the mysterious happenings are. It's a draub, basic, go to cabin movie with no intensity or "effort".<br /><br />THE SCREENPLAY: I usually give credit to indie screenwriters, it's hard work when you are starting out...but this is crap. The story is flat - it leaves you emotionless the entire movie. The dialogue is extremely weak and predictable boasting lines of "Woah, you totally freaked me out" and "I was wondering if you'd uh...if you'd like to..uh, would you come to the cabin with me?". It makes me want to rip out all my hair, one strand at a time and feed it to myself.<br /><br />THE CHARACTERS: HOLY CRAP!!!! Some have described the characters as flat, I want to take it one step further and say that they actually have a reverse character arch.. They actually start working on a parallel universe and almost start acting backwards...<br /><br />THE ACTORS: Worse than the characters are the actors. They take already poor written characters and add in terrible high school drama acting. The "Woah you totally freaked me out" was said so monotone and slow - like it was dumbed down. I could complain for hours on the actors alone.<br /><br />TECHNICAL: LIGHTING: An eight year old would be disappointed with lighting on this movie. Too shadowy in areas, too bleached in others. The director shouldn't use light as an emotion until he learns how to light a basic scene properly. Baby Steps! SOUND: How many sound guys does it take to make a really shotty sounding movie? 9. With that many sound guys this should sound amazing but quite the opposite has occured. There is one scene in particular that really sticks out, these guys are driving in a car and the sound of the car changes with every camera angle....WEAK! CAMERA: Learn to use it.<br /><br />Anyway, I'm running out of complaining space.....rent it - I dare you...Rent it and learn from it...give it a 1 rating..it deserves it.<br /><br />Signing off... Amanda Christmas
# Spoilers ahead if you want to call them that...  I would almost recommend this film just so people can truly see a 1/10. Where to begin, we'll start from the top...  THE STORY: Don't believe the premise - the movie has nothing to do with abandoned cars, and people finially understanding what the mysterious happenings are. It's a draub, basic, go to cabin movie with no intensity or "effort".  THE SCREENPLAY: I usually give credit to indie screenwriters, it's hard work when you are starting out...but this is crap. The story is flat - it leaves you emotionless the entire movie. The dialogue is extremely weak and predictable boasting lines of "Woah, you totally freaked me out" and "I was wondering if you'd uh...if you'd like to..uh, would you come to the cabin with me?". It makes me want to rip out all my hair, one strand at a time and feed it to myself.  THE CHARACTERS: HOLY CRAP!!!! Some have described the characters as flat, I want to take it one step further and say that they actually have a reverse character arch.. They actually start working on a parallel universe and almost start acting backwards...  THE ACTORS: Worse than the characters are the actors. They take already poor written characters and add in terrible high school drama acting. The "Woah you totally freaked me out" was said so monotone and slow - like it was dumbed down. I could complain for hours on the actors alone.  TECHNICAL: LIGHTING: An eight year old would be disappointed with lighting on this movie. Too shadowy in areas, too bleached in others. The director shouldn't use light as an emotion until he learns how to light a basic scene properly. Baby Steps! SOUND: How many sound guys does it take to make a really shotty sounding movie? 9. With that many sound guys this should sound amazing but quite the opposite has occured. There is one scene in particular that really sticks out, these guys are driving in a car and the sound of the car changes with every camera angle....WEAK! CAMERA: Learn to use it.  Anyway, I'm running out of complaining space.....rent it - I dare you...Rent it and learn from it...give it a 1 rating..it deserves it.  Signing off... Amanda Christmas

# %% [markdown]
# Применим ее:

# %%
train_df['review'] = train_df['review'].apply(lambda text: pattern.subn(' ', text)[0])
test_df['review'] = test_df['review'].apply(lambda text: pattern.subn(' ', text)[0])

# %%
import spacy

nlp = spacy.load('en', disable=['parser'])
def lemmatize(words,par, lemmer = nlp):
    lemmas = nlp(words)
    return str([w.text for w in lemmas if (not w.tag_ in par and w.is_alpha)])

# %%
test_df['review']
# Out:
# 0        ['formulaic', 'story', 'tired', 'cliches', 'I'...
# 1        ['is', 'entertaining', 'and', 'touching', 'ver...
# 2        ['Corey', 'Haim', 'is', 'never', 'going', 'to'...
# 3        ['you', 'believe', 'given', 'war', 'movie', 'c...
# 4        ['Carla', 'Gugino', 'literally', 'melts', 'scr...
#                                ...
# 24995    ['entry', 'does', 'contain', 'spoiler', 'It', ...
# 24996    ['is', 'multi', 'faceted', 'insightful', 'and'...
# 24997    ['movie', 'had', 'me', 'stuck', 'endless', 'lo...
# 24998    ['moving', 'was', 'intriguing', 'and', 'absorb...
# 24999    ['Film', 'failure', 'government', 'and', 'self...
# Name: review, Length: 25000, dtype: object

# %% [markdown]
# Уберем предлоги и союзы

# %%
train_df['review']=train_df['review'].apply(lemmatize,par=['DT'])
test_df['review']=test_df['review'].apply(lemmatize,par=['DT'])

# %% [markdown]
# Пора переходить к машинке!
#
# Как будем представлять текст? Проще всего - мешком слов.
#
# Заведём большой-большой словарь - список всех слов в обучающей выборке. Тогда каждое предложение можно представить в виде вектора, в котором будет записано, сколько раз встретилось каждое из возможных слов:
#
# ![bow](https://raw.githubusercontent.com/DanAnastasyev/DeepNLP-Course/master/Week%2001/Images/BOW.png)
#
# Простой и приятный способ сделать это - запихнуть тексты в `CountVectorizer`.
#
# Он имеет такую сигнатуру:
#
# ```python
# CountVectorizer(input='content', encoding='utf-8', decode_error='strict', strip_accents=None, lowercase=True, preprocessor=None, tokenizer=None, stop_words=None, token_pattern=r'(?u)\b\w\w+\b', ngram_range=(1, 1), analyzer='word', max_df=1.0, min_df=1, max_features=None, vocabulary=None, binary=False, dtype=<class ‘numpy.int64'>)
# ```
#
# Для начала обратим внимание на параметры `lowercase=True` и `max_df=1.0, min_df=1, max_features=None` - они про то, что по умолчанию все слова будут приводиться к нижнему регистру и в словарь попадут все слова, встречавшиеся в текстах.
#
# При желании можно было бы убрать слишком редкие или слишком частотные слова - пока не будем этого делать.
#
# Посмотрим на простом примере, как он будет работать:

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()

dummy_data = ['The movie was excellent',
              'the movie was awful']

dummy_matrix = vectorizer.fit_transform(dummy_data)

print(dummy_matrix.toarray())
print(vectorizer.get_feature_names())
# Out:
# [[0 1 1 1 1]
#  [1 0 1 1 1]]
# ['awful', 'excellent', 'movie', 'the', 'was']

# %% [markdown]
# *Как именно vectorizer определяет границы слов? Обратите внимание на параметр `token_pattern=r'(?u)\b\w\w+\b'` - как он будет работать?*
#
# Запустим его на реальных данных:

# %%
vectorizer = CountVectorizer()
vectorizer.fit(train_df['review'].values)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %% [markdown]
# Попробуем кого-нибудь таки сконвертировать

# %%
vectorizer.transform([train_df['review'].iloc[3]])
# Out:
# <1x74849 sparse matrix of type '<class 'numpy.int64'>'
# 	with 206 stored elements in Compressed Sparse Row format>

# %% [markdown]
# То, что и хотели - вектор с bow (т.е. bag-of-words) представлением исходного текста.
#
# И чем эта информация может помочь? Ну, всё тем же - какие-то слова носят положительный окрас, какие-то - отрицательный. Большинство вообще нейтральный, да.
#
# ![bow with weights](https://github.com/DanAnastasyev/DeepNLP-Course/raw/master/Week%2001/Images/BOW_weights.png)
#
# Хочется, наверное, подобрать коэффициенты, которые будут определять уровень окраса, да? Подбирать нужно по обучающей выборке, а не как мы перед этим делали.
#
# Например, для выборки
# ```
# 1   The movie was excellent
# 0   the movie was awful
# ```
# легко подобрать коэффициенты на глазок: что-нибудь вроде `+1` для `excellent`,  `-1` для `awful` и по нулям всем остальным.
#
# Построим линейную модель, которая станет этим заниматься. Она будет учиться строить разделяющую гиперплоскость в пространстве bow-векторов.
#
# Проверим, как справится логистическая регрессия с нашей супер-выборкой из пары предложений

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

dummy_data = ['The movie was excellent',
              'the movie was awful']
dummy_labels = [1, 0]

vectorizer = CountVectorizer()
classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(dummy_data, dummy_labels)

print(vectorizer.get_feature_names())
print(classifier.coef_)
# Out:
# ['awful', 'excellent', 'movie', 'the', 'was']
# [[-0.40104279  0.40104279  0.          0.          0.        ]]

# %% [markdown]
# Получилось что надо.
#
# Запустим теперь её на реальных данных.

# %%
model.fit(train_df['review'], train_df['is_positive'])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Pipeline(memory=None,
#          steps=[('vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=1,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=None, vocabulary=None)),
#                 ('classifier',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=100,
#                                     multi_class='auto', n_jobs=None,
#                                     penalty='l2', random_state=None,
#                                     solver='lbfgs', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %%
from sklearn.metrics import accuracy_score

def eval_model(model, test_df):
    preds = model.predict(test_df['review'])
    print('Test accuracy = {:.2%}'.format(accuracy_score(test_df['is_positive'], preds)))
    
eval_model(model, test_df)
# Out:
# Test accuracy = 86.58%

# %% [markdown]
# Прогресс!
#
# Хочется как-то посмотреть, что заинтересовало классификатор. К счастью, сделать это совсем просто:

# %%
import eli5
eli5.show_weights(classifier, vec=vectorizer, top=40)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.49%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.824
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         refreshing
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.73%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.783
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         wonderfully
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.60%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.640
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         funniest
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.14%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.554
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         rare
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.20%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.544
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         surprisingly
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.14%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.395
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         superb
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.390
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         subtle
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.57%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.330
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         incredible
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.87%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.284
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         delightful
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.17%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.239
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         flawless
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 88.17%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 36650 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 88.15%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 36120 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 88.15%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.242
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         mildly
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 88.06%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.255
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         unwatchable
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 88.05%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.257
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dreadful
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 88.04%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.259
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         wooden
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.97%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.269
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         weak
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.92%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.277
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         lame
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.89%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.281
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         baldwin
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.287
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         lousy
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.71%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.309
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         redeeming
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.53%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.336
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dull
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.41%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.3

# %% [markdown]
# Посмотрим на конкретные примеры его работы:

# %%
print('Positive' if test_df['is_positive'].iloc[1] else 'Negative')
eli5.show_prediction(classifier, test_df['review'].iloc[1], vec=vectorizer, 
                     targets=['positive'], target_names=['negative', 'positive'])
# Out:
# Positive
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>1.000</b>, score <b>20.071</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +20.084
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 99.88%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.013
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">[&#x27;</span><span style="background-color: hsl(120, 100.00%, 93.47%); opacity: 0.82" title="0.086">is</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 70.37%); opacity: 0.93" title="0.743">both</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 71.46%); opacity: 0.92" title="0.704">entertaining</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 92.28%); opacity: 0.82" title="0.109">and</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="1.141">touching</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 95.31%); opacity: 0.81" title="-0.053">version</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 94.34%); opacity: 0.81" title="-0.070">of</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 82.58%); opacity: 0.86" title="0.348">classic</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 92.16%); opacity: 0.82" title="0.111">tale</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 86.89%); opacity: 0.84" title="0.232">also</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 88.31%); opacity: 0.83" title="0.197">quite</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 86.10%); opacity: 0.84" title="0.252">intelligent</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 87.92%); opacity: 0.84" title="-0.206">not</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 94.34%); opacity: 0.81" title="-0.070">of</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 99.27%); opacity: 0.80" title="0.004">me</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 89.90%); opacity: 0.83" title="0.160">tarzan</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 89.41%); opacity: 0.83" title="0.171">you</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 85.73%); opacity: 0.85" title="0.262">jane</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 92.58%); opacity: 0.82" title="0.103">school</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 98.02%); opacity: 0.80" title="-0.016">at</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 92.63%); opacity: 0.82" title="-0.102">all</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 93.15%); opacity: 0.82" title="0.092">it</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 84.80%); opacity: 0.85" title="0.287">famous</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 99.41%); opacity: 0.80" title="0.003">story</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 94.34%); opacity: 0.81" title="-0.070">of</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 94.71%); opacity: 0.81" title="-0.063">child</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 97.40%); opacity: 0.80" title="-0.023">reared</span><span style="opacity: ...

# %%
print('Positive' if test_df['is_positive'].iloc[6] else 'Negative')
eli5.show_prediction(classifier, test_df['review'].iloc[6], vec=vectorizer, 
                     targets=['positive'], target_names=['negative', 'positive'])
# Out:
# Negative
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-9.524</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 99.80%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.013
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -9.511
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">[&#x27;</span><span style="background-color: hsl(0, 100.00%, 98.02%); opacity: 0.80" title="-0.019">movie</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 94.40%); opacity: 0.81" title="0.086">is</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 68.65%); opacity: 0.94" title="-1.002">terrible</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 94.12%); opacity: 0.81" title="0.092">it</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 96.68%); opacity: 0.81" title="-0.041">was</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 96.23%); opacity: 0.81" title="0.049">so</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 88.50%); opacity: 0.83" title="-0.239">difficult</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 99.25%); opacity: 0.80" title="0.005">to</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 94.16%); opacity: 0.81" title="-0.091">believe</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 99.20%); opacity: 0.80" title="-0.005">that</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 80.79%); opacity: 0.87" title="-0.497">katie</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 86.24%); opacity: 0.84" title="0.309">became</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 82.67%); opacity: 0.86" title="0.430">heartfelt</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 95.63%); opacity: 0.81" title="0.060">teenager</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 99.14%); opacity: 0.80" title="-0.006">with</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 85.67%); opacity: 0.85" title="-0.327">power</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 99.25%); opacity: 0.80" title="0.005">to</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 60.00%); opacity: 1.00" title="-1.419">save</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 90.00%); opacity: 0.83" title="0.196">pity</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 88.37%); opacity: 0.83" title="0.243">chinese</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 95.69%); opacity: 0.81" title="0.059">people</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 98.02%); opacity: 0.80" title="-0.019">movie</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 90.26%); opacity: 0.83" title="-0.188">did</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 98.52%); opacity: 0.80" title="-0.013">show</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 88.30%); opacity: 0.83" title="-0.245">convincing</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 99.18%); opacity: 0.80" title="-0.006">argument</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 99.25%); opacity: 0.80" title="0.005">to</span><span style="opac ...

# %% [markdown]
# Посмотрим на примеры неправильной классификации, наконец:

# %%
import numpy as np

preds = model.predict(test_df['review'])
incorrect_pred_index = np.random.choice(np.where(preds != test_df['is_positive'])[0])

eli5.show_prediction(classifier, test_df['review'].iloc[incorrect_pred_index],
                     vec=vectorizer, targets=['positive'], target_names=['negative', 'positive'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>0.129</b>, score <b>-1.913</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 99.39%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.013
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.900
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">[&#x27;</span><span style="background-color: hsl(0, 100.00%, 79.12%); opacity: 0.88" title="-0.356">subject</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 93.32%); opacity: 0.82" title="-0.070">of</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 97.27%); opacity: 0.80" title="-0.019">movie</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 92.30%); opacity: 0.82" title="0.086">is</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 68.95%); opacity: 0.94" title="-0.627">disturbing</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 98.95%); opacity: 0.80" title="-0.005">how</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 81.45%); opacity: 0.87" title="-0.301">could</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 68.15%); opacity: 0.94" title="-0.650">otherwise</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 83.60%); opacity: 0.86" title="0.252">intelligent</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 83.03%); opacity: 0.86" title="-0.265">religious</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 96.53%); opacity: 0.81" title="-0.027">hard</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 82.93%); opacity: 0.86" title="-0.267">working</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 90.88%); opacity: 0.82" title="0.109">and</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 80.69%); opacity: 0.87" title="-0.318">sincere</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 91.11%); opacity: 0.82" title="0.105">white</span><span style="opacity: 0.80">&#x27;, &#x27;afrikaaners&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 82.00%); opacity: 0.86" title="0.288">treat</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 85.40%); opacity: 0.85" title="0.213">native</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 90.25%); opacity: 0.83" title="-0.120">blacks</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 94.83%); opacity: 0.81" title="0.049">so</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 98.93%); opacity: 0.80" title="0.005">cruelly</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 97.40%); opacity: 0.80" title="-0.018">for</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 94.83%); opacity: 0.81" title="0.049">so</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 97.24%); opacity: 0.80" title="0.020">long</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 97.27%); opacity: 0.80" title="-0.019">movie</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 72.09%); opacity: 0.92" title="0.539">answers</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 93.21%); opacity: 0.82" title="0.072">question</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 90.88%); opacity: 0.82" titl ...
#     </p>

# %% [markdown]
# ## Придумываем новые признаки

# %% [markdown]
# ### Tf-idf
#
# Сейчас мы на все слова смотрим с одинаковым весом - хотя какие-то из них более редкие, какие-то более частые, и эта частотность - полезная, вообще говоря, информация.
#
# Самый простой способ добавить статистическую информацию о частотностях - сделать *tf-idf* взвешивание:
#
# $$\text{tf-idf}(t, d) = \text{tf}(t, d) \times \text{idf}(t)$$
#
# *tf* - term-frequency - частотность слова `t` в конкретном документе `d` (рецензии в нашем случае). Это ровно то, что мы уже считали.
#
# *idf* - inverse document-frequency - коэффициент, который тем больше, чем в меньшем числе документов встречалось данное слово. Считается как-нибудь так:
# $$\text{idf}(t) = \text{log}\frac{1 + n_d}{1 + n_{d(t)}} + 1$$
# где $n_d$ - число всех документов, а $n_{d(t)}$ - число документов со словом `t`.
#
# Использовать его просто - нужно заменить `CountVectorizer` на `TfidfVectorizer`.
#
# **Задание** Попробуйте запустить `TfidfVectorizer`. Посмотрите на ошибки, которые он научился исправлять, и на ошибки, которые он начал делать - по сравнению с `CountVectorizer`.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_df['review'], train_df['is_positive'])

eval_model(model, test_df)
# Out:
# Test accuracy = 88.42%

# %%
eli5.show_weights(classifier, vec=vectorizer, top=40)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.68%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.477
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         great
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.86%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.165
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         excellent
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.66%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.149
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         best
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.28%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.807
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         perfect
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.57%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.655
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         wonderful
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.50%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.164
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         amazing
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.74%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.042
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         well
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.21%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.804
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         favorite
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.24%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.786
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         loved
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.38%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.716
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         love
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.42%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.698
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         today
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.44%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.686
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         fun
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.68%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.567
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         enjoyed
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 89.68%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 36503 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 90.05%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 36267 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 90.05%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.385
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         save
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 90.03%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.396
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         avoid
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 90.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.412
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         supposed
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.88%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.468
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         instead
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.87%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.475
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         even
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.482
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         disappointing
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.83%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.494
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         disappointment
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.79%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.515
#     </td

# %%
preds = model.predict(test_df['review'])
incorrect_pred_index = np.random.choice(np.where(preds != test_df['is_positive'])[0])

eli5.show_prediction(classifier, test_df['review'].iloc[incorrect_pred_index],
                     vec=vectorizer, targets=['positive'], target_names=['negative', 'positive'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>0.739</b>, score <b>1.040</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.194
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 95.22%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.154
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">[&#x27;</span><span style="background-color: hsl(120, 100.00%, 91.82%); opacity: 0.82" title="0.030">as</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 92.12%); opacity: 0.82" title="0.028">recent</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 98.63%); opacity: 0.80" title="0.002">convert</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 94.29%); opacity: 0.81" title="-0.018">to</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 97.31%); opacity: 0.80" title="0.006">curb</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 93.08%); opacity: 0.82" title="-0.024">your</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 93.43%); opacity: 0.82" title="0.022">enthusiasm</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 96.70%); opacity: 0.81" title="0.008">which</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 96.79%); opacity: 0.81" title="-0.008">prompted</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 87.40%); opacity: 0.84" title="0.056">my</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 83.49%); opacity: 0.86" title="0.082">viewing</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 98.10%); opacity: 0.80" title="0.004">of</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 80.06%); opacity: 0.87" title="0.107">season</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 78.01%); opacity: 0.89" title="0.123">episodes</span><span style="opacity: 0.80">&#x27;, &#x27;i&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 97.18%); opacity: 0.80" title="-0.007">expected</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 88.61%); opacity: 0.83" title="0.048">more</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 89.43%); opacity: 0.83" title="-0.043">much</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 88.61%); opacity: 0.83" title="0.048">more</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 96.66%); opacity: 0.81" title="0.008">from</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 87.96%); opacity: 0.84" title="0.052">jeff</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 96.51%); opacity: 0.81" title="-0.009">efforts</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 91.59%); opacity: 0.82" title="0.031">when</span><span style="opacity: 0.80">&#x27;, &#x27;i&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 91.08%); opacity: 0.82" title="0.034">view</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 94.83%); opacity: 0.81" title="0.016">film</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(0, 100.00%, 94.63%); opacity: 0.81" title="-0.016">offering</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 94.47%); opacity: 0.81" title="0.017">slice</span><span style="opacity: 0.80">&#x27;, &#x27;</span><span style="background-color: hsl(120, 100.00%, 98.10%); opacity: 0.80" tit ...

# %% [markdown]
# ### N-граммы слов
#
# До сих пор мы смотрели на тексты как на мешок слов - но очевидно, что есть разница между `good movie` и `not good movie`.
#
# Добавим информацию (хоть какую-то) о последовательностях слов - будем извлекать еще и биграммы слов.
#
# В Vectorizer'ах для этого есть параметр `ngram_range=(n_1, n_2)` - он говорит, что нужны n_1-...n_2-граммы.
#
# **Задание** Попробуйте увеличенный range и поинтерпретируйте полученный результат.

# %%
for i in range(2,5):

  vectorizer = TfidfVectorizer(ngram_range=(1, i))
  classifier = LogisticRegression()

  model = Pipeline([
      ('vectorizer', vectorizer),
      ('classifier', classifier)
  ])

  print(i)

  model.fit(train_df['review'], train_df['is_positive'])

  eval_model(model, test_df)
# Out:
# 2
# Test accuracy = 88.37%
# 3
# Test accuracy = 87.47%
# 4
# Test accuracy = 86.76%

# %% [markdown]
# Увеличение диапозона уменьшает точность

# %% [markdown]
# ### N-граммы символов
#
# Символьные n-граммы дают простой способ выучить полезные корни и суффиксы, не связываясь с этой вашей лингвистикой - только статистика, только хардкор.
#
# Например, слово `badass` мы можем представить в виде такой последовательности триграмм:
#
# `##b #ba bad ada das ass ss# s##`
#
# So interpretable, неправда ли?
#
# Реализовать это дело всё так же просто - нужно поставить `analyzer='char'` в вашем любимом Vectorizer'е и выбрать размер `ngram_range`.
#
# **Задание** Запилите классификатор на n-граммах символов и визуализируйте его.

# %%
vectorizer = TfidfVectorizer(ngram_range=(2, 6), max_features=20000, analyzer='char')
classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_df['review'], train_df['is_positive'])

eval_model(model, test_df)
# Out:
# Test accuracy = 85.85%

# %%
print('Positive' if test_df['is_positive'].iloc[1] else 'Negative')
eli5.show_prediction(classifier, test_df['review'].iloc[1], vec=vectorizer, 
                     targets=['positive'], target_names=['negative', 'positive'])
# Out:
# Positive
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>0.892</b>, score <b>2.112</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.111
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.41%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.001
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 90.25%); opacity: 0.83" title="0.002">[</span><span style="background-color: hsl(120, 100.00%, 87.63%); opacity: 0.84" title="0.003">&#x27;</span><span style="background-color: hsl(120, 100.00%, 85.57%); opacity: 0.85" title="0.003">i</span><span style="background-color: hsl(120, 100.00%, 83.68%); opacity: 0.86" title="0.004">s</span><span style="background-color: hsl(120, 100.00%, 90.39%); opacity: 0.83" title="0.002">&#x27;</span><span style="background-color: hsl(0, 100.00%, 93.42%); opacity: 0.82" title="-0.001">,</span><span style="background-color: hsl(0, 100.00%, 85.40%); opacity: 0.85" title="-0.003"> </span><span style="background-color: hsl(0, 100.00%, 81.80%); opacity: 0.86" title="-0.005">&#x27;</span><span style="background-color: hsl(0, 100.00%, 81.34%); opacity: 0.87" title="-0.005">b</span><span style="background-color: hsl(0, 100.00%, 85.55%); opacity: 0.85" title="-0.003">o</span><span style="background-color: hsl(120, 100.00%, 97.57%); opacity: 0.80" title="0.000">t</span><span style="background-color: hsl(120, 100.00%, 88.55%); opacity: 0.83" title="0.002">h</span><span style="background-color: hsl(120, 100.00%, 87.93%); opacity: 0.84" title="0.003">&#x27;</span><span style="background-color: hsl(120, 100.00%, 94.60%); opacity: 0.81" title="0.001">,</span><span style="background-color: hsl(120, 100.00%, 95.69%); opacity: 0.81" title="0.001"> </span><span style="background-color: hsl(120, 100.00%, 89.80%); opacity: 0.83" title="0.002">&#x27;</span><span style="background-color: hsl(120, 100.00%, 83.68%); opacity: 0.86" title="0.004">e</span><span style="background-color: hsl(120, 100.00%, 83.40%); opacity: 0.86" title="0.004">n</span><span style="background-color: hsl(120, 100.00%, 87.55%); opacity: 0.84" title="0.003">t</span><span style="background-color: hsl(120, 100.00%, 82.58%); opacity: 0.86" title="0.004">e</span><span style="background-color: hsl(120, 100.00%, 75.84%); opacity: 0.90" title="0.007">r</span><span style="background-color: hsl(120, 100.00%, 73.73%); opacity: 0.91" title="0.008">t</span><span style="background-color: hsl(120, 100.00%, 76.49%); opacity: 0.89" title="0.007">a</span><span style="background-color: hsl(120, 100.00%, 79.13%); opacity: 0.88" title="0.006">i</span><span style="background-color: hsl(120, 100.00%, 79.92%); opacity: 0.87" title="0.005">n</span><span style="background-color: hsl(120, 100.00%, 87.62%); opacity: 0.84" title="0.003">i</span><span style="background-color: hsl(0, 100.00%, 94.56%); opacity: 0.81" title="-0.001">n</span><span style="background-color: hsl(0, 100.00%, 88.20%); opacity: 0.83" title="-0.002">g</span><span style="background-color: hsl(0, 100.00%, 86.15%); opacity: 0.84" title="-0.003">&#x27;</span><span style="background-color: hsl(0, 100.00%, 89.02%); opacity: 0.83" title="-0.002">,</span><span style="background-color: hsl(0, 100.00%, 96.81%); opacity: 0.81" title="-0.000"> </span><span style="background-color: hsl(120, 100.00%, 87.57%); opacity: 0.84" title="0.003">&#x27;</span><span style="background-color: hsl(120, 100.00%, 77.00%); opacity: 0.89" title="0.006">a</span><span style="background-color: hsl(120, 100.00%, 72.53%); opacity: 0.92" title="0.008">n</span><span style="background-color: hsl(120, 100.00%, 82.32%); opacity: 0.86" title="0.004">d</span><span style="background-color: hsl(120, 100.00%, 93.56%); opacity: 0.81" title="0.001">&#x27;</span><span style="background-color: hsl(0, 100.00%, 99.39%); opacity: 0.80" title="-0.000">,</span><span style="background-color: hsl(120, 100.00%, 95.84%); opacity: 0.81" title="0.001"> </span><span style="background-color: hsl(120, 100.00%, 86.63%); opacity: 0.84" title="0.003">&#x27;</span><span style="background-color: hsl(120, 100.00%, 77.33%); opacity: 0.89" title="0.006">t</span><span style="background-color: hsl(120, 100.00%, 71.24%); opacity: 0.92" title="0.009">o</span><span style="background-color: hsl(120, 100.00%, 72.32%); opaci ...

# %% [markdown]
# ## Подключаем лингвистику

# %% [markdown]
# ### Лемматизация и стемминг
#
# Если присмотреться, можно найти формы одного слова с разной семантической окраской по мнению классификатора. Или нет?
#
# **Задание** Найти формы слова с разной семантической окраской.
#
# Поверя, что они есть, попробуем что-нибудь с этим сделать.
#
# Например, лемматизируем - сведем к начальной форме все слова. Поможет в этом библиотека spacy.

# %%
import spacy
from spacy import displacy

nlp = spacy.load('en', disable=['parser'])

docs = [doc for doc in nlp.pipe(train_df.review.values[:50])]

# %%
train_df_lem=train_df.copy()
test_df_lem=test_df.copy()
train_df_lem.review=train_df.review.apply(lambda x:str([w.lemma_ for w in nlp(x) if w.is_alpha]))
test_df_lem.review=test_df.review.apply(lambda x:str([w.lemma_ for w in nlp(x) if w.is_alpha]))

# %%
vectorizer = TfidfVectorizer()
classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_df_lem['review'], train_df_lem['is_positive'])

eval_model(model, test_df_lem)
# Out:
# Test accuracy = 87.93%

# %% [markdown]
# Весь этот процесс очень долгий, поэтому я предподсчитал всё.

# %%
import pickle

with open('train_docs.pkl', 'rb') as f:
    train_docs = pickle.load(f)
    
with open('test_docs.pkl', 'rb') as f:
    test_docs = pickle.load(f)

# %%
from nltk import PorterStemmer

stemmer = PorterStemmer()

print(stemmer.stem('привет'))
print(stemmer.stem('becomes'))
print(stemmer.stem('became'))
# Out:
# привет
# becom
# becam

# %%
train_df_st=train_df.copy()
test_df_st=test_df.copy()

train_df_st['review']=train_df_st['review'].apply(lambda x: [stemmer.stem(word) for word in re.findall('\w+',x)])
test_df_st['review']=test_df_st['review'].apply(lambda x: [stemmer.stem(word) for word in re.findall('\w+',x)])

# %%
vectorizer = TfidfVectorizer()
classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_df_st['review'].apply(str), train_df_st['is_positive'])

test_df_st.review=test_df_st.review.apply(str)

eval_model(model, test_df_st)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Test accuracy = 88.17%

# %% [markdown]
# **Задание** Попробуйте вместо лемм классифицировать основы.

# %% [markdown]
# Лемматизация и стэмминг в данном случае существенного влияния на показатели не оказывает

# %% [markdown]
# ### NER
#
# В текстах рецензий очень много именованных сущностей. Вот, например:

# %%
displacy.render(docs[0], style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dreamgirls
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , despite its fistful of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tony
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  wins in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     an incredibly weak year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  on
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Broadway
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# , has never been what one would call a jewel in the crown of stage musicals. However, that is not to say that in the right cinematic hands it could not be fleshed out and polished into something worthwhile on-screen. Unfortunately, what transfers to the screen is basically a slavishly faithful version of the stage hit with all of its inherent weaknesses intact.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     First
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# , the score has never been one of the strong points of this production and the film does not change that factor. There are lots of songs (perhaps too many?), but few of them are especially memorable. The closest any come to catchy tunes are the title song and
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     One Night
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  Only - the much acclaimed And I Am Telling You That I Am Not Going is less a great song than it is a dramatic set piece for the character of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Effie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jennifer Hudson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ). The film is slick and technically well-produced, but the story and characters are surprisingly thin and lacking in any resonance. There is some interest in the opening moments, watching
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jamie Foxx's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Svengali-like manager manipulate his acts to the top, but that takes a back seat in the latter portion of the film, when the story conveniently tries to cast him as a villain, despite his having been right from a business stand-point for a good majority of the film.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Beyonce Knowles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is lovely and sings her songs perfectly well, but is stuck with a character who is basically all surface glitz.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anika Noni Rose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  as the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  member of the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dreamgirls
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  trio literally has nothing to do for the entire film.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Eddie Murphy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  acquits himself well as a singer obviously based on
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James Brown
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , but the role is not especially meaty and ultimately has little impact.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Foxx
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  would seem ideal casting, but he seems oddly withdrawn and bored. The film's biggest selling point is surely former
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American Idol
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  contestant/
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Oscar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  winner
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jennifer Hudson
#     <span style="font-size: 0.8em; font-wei

# %% [markdown]
# Вообще говоря, почему вдруг какой-нибудь Депп должен нести семантическую окраску? Однако оказывается, что классификатор выучивает, что какие-то имена чаще в положительных рецензиях - или наоборот. Это похоже на переобучение - почему бы не попробовать вырезать сущности?
#
# **Задание** Удалите из текстов какие-то из сущностей, пользуясь координатами из запикленных файлов. Описание сущностей можно посмотреть [здесь](https://spacy.io/api/annotation#named-entities). Запустите классификатор.

# %%
train_df['review']=train_df['review'].apply(lemmatize,par=['NNP'])
test_df['review']=test_df['review'].apply(lemmatize,par=['NNP'])

# %%
import numpy as np

# %%
vectorizer = TfidfVectorizer()
classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_df['review'], train_df['is_positive'])

eval_model(model, test_df)
# Out:
# Test accuracy = 88.26%

# %% [markdown]
# Удаление сущностей также не оказывает значимого влияния на показатели

# %% [markdown]
# ## Включаем дип лёрнинг

# %% [markdown]
# Мы тут пришли deep learning'ом заниматься, а делаем почему-то модель на логистической регрессии. Как так?
#
# Попробуем запустить относительно стандартную модель для классификации текстов - сверточная сеть поверх словных эмбеддингов.
#
# Разбираться, что это за зверь, будем на следующих занятиях, а пока будем просто им пользоваться :)
#
# Каждое предложение нужно представлять набором слов - и сразу же начинаются проблемы. Во-первых, как ограничить длину предложения?
#
# Прикинем по гистограмме, какая длина нам подходит:

# %%
train_df['review']
# Out:
# 0        ['despite', 'its', 'fistful', 'of', 'wins', 'i...
# 1        ['show', 'comes', 'up', 'with', 'interesting',...
# 2        ['I', 'simply', 'love', 'movie', 'I', 'also', ...
# 3        ['Spoilers', 'ahead', 'if', 'you', 'want', 'to...
# 4        ['My', 'time', 'favorite', 'movie', 'I', 'have...
#                                ...
# 24995    ['I', 'am', 'big', 'fan', 'of', 'movie', 'but'...
# 24996    ['I', 'not', 'going', 'to', 'bother', 'with', ...
# 24997    ['movie', 'I', 'do', 'know', 'Why', 'they', 'w...
# 24998    ['Saw', 'film', 'on', 'yesterday', 'and', 'was...
# 24999    ['was', 'disappointment', 'none', 'of', 'nuanc...
# Name: review, Length: 25000, dtype: object

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

_, _, hist = plt.hist(train_df.review.apply(lambda text: len(text.split())), bins='auto')
hist
# Out:
# <a list of 231 Patch objects>

# %% [markdown]
# Кроме этого, нужно перенумеровать как-то слова.

# %%
from collections import Counter

words_counter = Counter((word for text in train_df.review for word in text.lower().split()))

word2idx = {
    '': 0,
    '<unk>': 1
}
for word, count in words_counter.most_common():
    if count < 10:
        break
        
    word2idx[word] = len(word2idx)
    
print('Words count', len(word2idx))
# Out:
# Words count 14783

# %% [markdown]
# **Задание** Сконвертируйте данные

# %%
def convert(texts, word2idx, max_text_len):
    data = np.zeros((len(texts), max_text_len), dtype=np.int)
    
    for inx, text in enumerate(texts):
        result = []
        for word in text.split():
            if word in word2idx:
                result.append(word2idx[word])
        padding = [0]*(max_text_len - len(result))
        data[inx] = np.array(padding + result[-max_text_len:], dtype=np.int)
    return data

X_train = convert(train_df.review, word2idx, 1000)
X_test = convert(test_df.review, word2idx, 1000)

# %%
X_train
# Out:
# array([[    0,     0,     0, ...,    27,  2173,    14],
#        [    0,     0,     0, ...,    43,     2,  3361],
#        [    0,     0,     0, ...,    86,  1326,   106],
#        ...,
#        [    0,     0,     0, ...,    12,     7, 17818],
#        [    0,     0,     0, ...,    73,    27,  3112],
#        [    0,     0,     0, ...,    28,    10, 23594]])

# %%
st=StandardScaler()
X_st=X_train.copy()
X_st=st.fit_transform(X_st)
X_st_test=X_test.copy()
st=StandardScaler()
X_st_test=st.fit_transform(X_st_test)

# %% [markdown]
# Поставим учиться модельку на keras.
#
# *Напоминание*: на keras, чтобы обучить модель, нужно
# 1. Определить модель, например:
# ```python
# model = Sequential()
# model.add(Dense(1, activation='sigmoid', input_dim=NUM_WORDS))
# ```
# 2. Задать функцию потерь и оптимизатор:
# ```python
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# ```
#
# 3. Запустить обучение:
# ```python
# model.fit(X_train, y_train,
#           batch_size=32,
#           epochs=3,
#           validation_data=(X_test, y_test))
# ```
#
# В NLP чаще всего ставятся задачи классификации, поэтому нужно запомнить такие функции потерь:
#
# *   **categorical_crossentropy** - для многоклассовой классификации, в качестве меток должны передаваться one-hot-encoding вектора
# *   **sparse_categorical_crossentropy** - аналогично предыдущему, но в качестве меток нужно передавать просто индексы соответствующих классов
# *   **binary_crossentropy** - для бинарной классификации
#
#
# В качестве оптимизатора обычно используют `sgd` или `adam`.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.5.0'

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalMaxPooling1D, Dropout

# %%
model = Sequential([
    Embedding(input_dim=len(word2idx), output_dim=64, input_shape=(X_train.shape[1],)),
    GlobalMaxPooling1D(),
    Dense(units=10, activation='relu'),
    Dense(units=10, activation='relu'),
    
    Dense(units=1, activation='sigmoid')
])

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 1000, 64)          946112
# _________________________________________________________________
# global_max_pooling1d_5 (Glob (None, 64)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                650
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 946,883
# Trainable params: 946,883
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, train_df.is_positive, batch_size=128, epochs=10, 
          validation_data=(X_test, test_df.is_positive))
# Out:
# Epoch 1/10
# 196/196 [==============================] - 16s 77ms/step - loss: 0.5914 - accuracy: 0.7662 - val_loss: 0.4010 - val_accuracy: 0.8377
# Epoch 2/10
# 196/196 [==============================] - 15s 77ms/step - loss: 0.3131 - accuracy: 0.8719 - val_loss: 0.3117 - val_accuracy: 0.8638
# Epoch 3/10
# 196/196 [==============================] - 15s 76ms/step - loss: 0.2199 - accuracy: 0.9156 - val_loss: 0.3058 - val_accuracy: 0.8694
# Epoch 4/10
# 196/196 [==============================] - 15s 76ms/step - loss: 0.1513 - accuracy: 0.9488 - val_loss: 0.3195 - val_accuracy: 0.8700
# Epoch 5/10
# 196/196 [==============================] - 15s 76ms/step - loss: 0.0967 - accuracy: 0.9709 - val_loss: 0.3518 - val_accuracy: 0.8685
# Epoch 6/10
# 196/196 [==============================] - 15s 76ms/step - loss: 0.0564 - accuracy: 0.9856 - val_loss: 0.3952 - val_accuracy: 0.8642
# Epoch 7/10
# 196/196 [==============================] - 15s 76ms/step - loss: 0.0298 - accuracy: 0.9943 - val_loss: 0.4421 - val_accuracy: 0.8608
# Epoch 8/10
# 196/196 [==============================] - 15s 76ms/step - loss: 0.0146 - accuracy: 0.9989 - val_loss: 0.4853 - val_accuracy: 0.8600
# Epoch 9/10
# 196/196 [==============================] - 15s 76ms/step - loss: 0.0077 - accuracy: 0.9995 - val_loss: 0.5216 - val_accuracy: 0.8586
# Epoch 10/10
# 196/196 [==============================] - 15s 75ms/step - loss: 0.0045 - accuracy: 0.9998 - val_loss: 0.5515 - val_accuracy: 0.8582

# %% [markdown]
# Модель быстро переобучается, показатели на тесте не превосходят показатели логистической регрессии

# %% [markdown]
# **Задание** Подсчитайте качество модели на тесте
